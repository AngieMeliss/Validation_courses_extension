# %% [markdown]
# # Validaciones por plantilla:
# Ministerio de Educación HECAA V4.9
#
# ---

# %% [markdown]
# > # General functions

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pathlib
from pathlib import Path
# !pip install email-validator
from email_validator import validate_email, EmailNotValidError
import itertools
import datetime
import zoneinfo
import pandas as pd
import numpy as np
from numpy import empty

# %%
def validate_column (col_name, fields_found_list, fields_not_found_list, validate_fun):
  ''' search the column, if it's founded apply the funcition personalized, if doesn't found, report it'''
  try:
    validate_fun      # try to use the validate function
    fields_found_list.append('- ' + str(col_name))    # add the columns found
  except:
    fields_not_found_list.append('- ' + str(col_name))    # if there's an error, it's because didn't find the sheet

# %%
def sheet_df_generate (fields_report, sheet_name):
  ''' generates the dataframe for adding to the excel document '''
  try:
    columns_names = list(fields_report[sheet_name].keys())    # obtain the names of the columns of dataframe
    match len(columns_names):
      case 5:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]]
          )),
          columns = columns_names)
      case 6:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]]
          )),
          columns = columns_names)
      case 7:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]]
          )),
          columns = columns_names)
      case 8:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]],
              fields_report[sheet_name][columns_names[7]]
          )),
          columns = columns_names)
      case 13:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]],
              fields_report[sheet_name][columns_names[7]],
              fields_report[sheet_name][columns_names[8]],
              fields_report[sheet_name][columns_names[9]],
              fields_report[sheet_name][columns_names[10]],
              fields_report[sheet_name][columns_names[11]],
              fields_report[sheet_name][columns_names[12]]
          )),
          columns = columns_names)
      case 14:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]],
              fields_report[sheet_name][columns_names[7]],
              fields_report[sheet_name][columns_names[8]],
              fields_report[sheet_name][columns_names[9]],
              fields_report[sheet_name][columns_names[10]],
              fields_report[sheet_name][columns_names[11]],
              fields_report[sheet_name][columns_names[12]],
              fields_report[sheet_name][columns_names[13]]
          )),
          columns = columns_names)
      case 16:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]],
              fields_report[sheet_name][columns_names[7]],
              fields_report[sheet_name][columns_names[8]],
              fields_report[sheet_name][columns_names[9]],
              fields_report[sheet_name][columns_names[10]],
              fields_report[sheet_name][columns_names[11]],
              fields_report[sheet_name][columns_names[12]],
              fields_report[sheet_name][columns_names[13]],
              fields_report[sheet_name][columns_names[14]],
              fields_report[sheet_name][columns_names[15]]
          )),
          columns = columns_names)
      case 17:
        sheet_report_Wout_spaces = pd.DataFrame(    # create the dataframe
          list(itertools.zip_longest(
              fields_report[sheet_name][columns_names[0]],
              fields_report[sheet_name][columns_names[1]],
              fields_report[sheet_name][columns_names[2]],
              fields_report[sheet_name][columns_names[3]],
              fields_report[sheet_name][columns_names[4]],
              fields_report[sheet_name][columns_names[5]],
              fields_report[sheet_name][columns_names[6]],
              fields_report[sheet_name][columns_names[7]],
              fields_report[sheet_name][columns_names[8]],
              fields_report[sheet_name][columns_names[9]],
              fields_report[sheet_name][columns_names[10]],
              fields_report[sheet_name][columns_names[11]],
              fields_report[sheet_name][columns_names[12]],
              fields_report[sheet_name][columns_names[13]],
              fields_report[sheet_name][columns_names[14]],
              fields_report[sheet_name][columns_names[15]],
              fields_report[sheet_name][columns_names[16]]
          )),
          columns = columns_names)

    sheet_report_W_spaces = sheet_report_Wout_spaces.fillna(value = '')     # add spaces to do the dataframe square, all the columns got the same lenght
    report_sheet = sheet_report_W_spaces [columns_names]
    return report_sheet
  except:
    print('Ha habido un error conviertiendo el dicionario ' + str(sheet_name) + 'a Dataframe')
    pass

# %%
def report_general_funct(date, doc_name, plantilla_rev_name, fields_found, fields_not_found):
  '''Generates the data of the first sheet, which is the general data of the book'''
  review_data = ['DOCUMENTO REVISADO: ' + str(doc_name),
                 'FECHA Y HORA DE REVISIÓN: ' + date]

  colms_sheet_general = ['REVISIÓN DE LA VALIDACIÓN DE PLANTILLA DE: ' + plantilla_rev_name,
                         'HOJAS Y CAMPOS ENCONTRADOS',
                         'CAMPOS NO ENCONTRADOS']

  general_report = pd.DataFrame(
      list(itertools.zip_longest(review_data, fields_found, fields_not_found)),
      columns = colms_sheet_general)

  general_report = general_report.fillna(value = '')    # add spaces to the dataframe, is required that all columns got the same lenght
  report_general = general_report [colms_sheet_general]

  return report_general

# %% [markdown]
# >> ## Validation functions

# %% [markdown]
# TIPO DE DATO
#
# ---

# %%
def validate_type (data, index_data, typee, dictionary, sheet, column):
  '''this function validate the type of data according to alphanumeric, numeric or date data'''

  if typee == 'numeric':
    try:
      int(data)
      return False
    except ValueError:
      try:
        if ((data is empty) or (data == '') or (np.isnan(data)) or (np.isnull(data))):
          pass
      except:
        dictionary[sheet][column].append(
            'la celda [' + str(column) + ', ' + str(index_data) + '] no es de tipo numérico')
  elif typee == 'date':
    try:
      if ((type(data) == pd._libs.tslibs.timestamps.Timestamp) or type(data) == datetime.datetime):
        pass
      else:
        dictionary[sheet][column].append(
            'la celda [' + str(column) + ', ' + str(index_data) + '] no es de tipo fecha:' + str(type(data)))
    except:
      pass

# %% [markdown]
# LONGITUD
#
# ---

# %%
def validate_lenght (data, index_data, valid_lenght, dictionary, sheet, column):
  '''this function validate the lenght of a cell comparing to a given maximum lenght'''
  try:
    real_lenght = len(str(data))
    try:
      if ((data is empty) or (data == '') or (np.isnan(data)) or (np.isnull(data))):
        # the data is empty
        pass
      else:
        if real_lenght > valid_lenght:
          dictionary[sheet][column].append(
              'la longitud de la celda [' + str(column) + ', ' + str(index_data) +
              '] es: ' + str(real_lenght) + ' y la máxima permitida es: ' + str(valid_lenght))
    except:
      if real_lenght > valid_lenght:
        dictionary[sheet][column].append(
            'la longitud de la celda [' + str(column) + ', ' + str(index_data) +
            '] es: ' + str(real_lenght) + ' y la máxima permitida es: ' + str(valid_lenght))
  except:
    dictionary[sheet][column].append(
        'el dato de la celda [' + str(column) + ', ' + str(index_data) + '] no se pudo convertir a texto. Hubo un error')

# %% [markdown]
# VALORES VALIDOS
#
# ---

# %%
def validate_values (data, index_data, file_valData_name, sheet_valData_name, column_valData_name, dictionary, sheet, column):
  '''validates that the given data coincides with some data contemplated in the templates'''
  try:
    valid_sheet = pd.read_excel(general_path + 'VALID_VALUES/' + file_valData_name, sheet_name = sheet_valData_name) #opens excel file and extract the valid values' sheet
    valid_values = valid_sheet[column_valData_name].tolist() # extract the column from the sheet, these are the valid values
    valid_values = [value for value in valid_values if pd.isnull(value) == False] # remove the empty values
    if data in valid_values:
      pass
    else:
      try:
        if ((data is empty) or (data == '') or (np.isnan(data)) or (np.isnull(data))): # if the data is empty
          pass
        else:
          dictionary[sheet][column].append(
              'el dato de la celda [' + str(column) + ', ' + str(index_data) + '] no es un valor válido')
      except:
        dictionary[sheet][column].append(     # the finding is stored
              'el dato de la celda [' + str(column) + ', ' + str(index_data) + '] no es un valor válido')
  except:
    dictionary[sheet][column].append(     # is there's an error, also the finding is stored
          'el dato de la celda [' + str(column) + ', ' + str(index_data) + '] presentó un error en la validación')

# %% [markdown]
# VALIDACIONES
#
# ---
#
# - Obligatorio

# %%
def validate_required (data, index_data, dictionary, sheet, column):
  ''' this function validate that the data is available, because the data is required'''

  try:
    if ((data is empty) or (data == '') or (np.isnan(data))):
      dictionary[sheet][column].append(     #  if the data is empty, the finding is stored
          'la celda [' +
          str(column) + ', ' + str(index_data) +
          '] está vacía y este campo es requerido')
  except:
    pass # if there is a value, there's an information

# %% [markdown]
# - Debe ser el año de un periodo abierto

# %%
def validate_year_open_period(data, index_data, year_openPeriod, dictionary, sheet, column):
  '''validates that the data coincides with the year given'''
  try:
    if ((data is empty) or (data == '') or (np.isnan(data)) ):
      pass    # the data is empty
    elif (data == year_openPeriod):
      pass    # the given year open period coincides with the data
    else:
      # if there isn't coincidence and is not empty, so it doesn't match and the finding is stored
      dictionary[sheet][column].append(
          'la celda [' + str(column) + ', ' + str(index_data) +
          '] debe ser el año de un periodo abierto: ' + str(year_openPeriod))
  except:
    try:
      if (data == year_openPeriod):
        pass    # the given year open period coincides with the data
      else:
        dictionary[sheet][column].append(     # if there isn't coincidence, the finding is stored
            'la celda [' + str(column) + ', ' + str(index_data) +
            '] debe ser el año de un periodo abierto: ' + str(year_openPeriod))
    except:
      pass

# %% [markdown]
# - El valor no puede ser negativo

# %%
def validate_negative (data, index_data, dictionary, sheet, column):
  '''validates that the data don't be a negative value'''
  try:
    int(data)
    if (data < 0):    # if the data is less than 0 (zero), the finding is stored
      dictionary[sheet][column].append(
          'la celda [' + str(column) + ', ' + str(index_data) + '] no puede ser negativa, y es: ' + str(data))
  except ValueError:
    pass

# %% [markdown]
# - La fecha debe estar entre 80 años atrás y la fecha actual

# %%
def validate_date_80_years_before (data, index_data, dictionary, sheet, column):
  '''validates that the data be between 80 years before and current date'''
  try:
    if ((datetime.datetime.now().year - data.year) > 80):     # if the difference between the current year and the data is greater than 80
      dictionary[sheet][column].append(
          'la fecha de la celda [' + str(column) + ', ' + str(index_data) + '] debe estar entre 80 años atrás y la fecha actual')
    else:
      pass
  except:
    pass

# %% [markdown]
# - La fecha final debe ser mayor a la fecha inicial

# %%
def validate_final_date_older_initial_date (data, index_data, all_sheet, initial_date_name, dictionary, sheet, column):
  '''validates that the data be older than a initial date'''
  try:
    initial_date = all_sheet.loc[index_data-2,initial_date_name]
    if initial_date > data :     # if the initial date is older than the data, the finding is stored
      dictionary[sheet][column].append(
            'la fecha de la celda [' + str(column) + ', ' + str(index_data) + '] debe ser mayor a la fecha inicial (' + str(initial_date) +' )')
    else:
      pass
  except:
    pass

# %% [markdown]
# - Obligatorio si ...

# %%
def validate_required_if(possibly_data_name, data, index_data, all_sheet, dictionary, sheet, column):
  '''validates that the data is able depending on existence of the data in other column'''
  try:
    possibly_data = all_sheet.loc[index_data-2,possibly_data_name]   # the data could be empty
    if ((data is empty) or (data == '') or (np.isnan(data))):
      try:
        if ((possibly_data is empty) or (possibly_data == '') or (np.isnan(possibly_data))):
          pass    # if the possible data is empty, this should be empty also, so nothing happens
        else:
          # but if the possible data have a value, this data couldn't be empty, is required
          dictionary[sheet][column].append(     # so the finding is stored
              'el valor de la celda [' + str(column) + ', ' + str(index_data) + '] es requerido porque la celda [' +
              str(possibly_data_name) + ', ' + str(index_data) + '] tiene un valor: ' + str(possibly_data))
      except:
        # here neither can be empty, should be a value, but also the finding is stored
        dictionary[sheet][column].append(
            'el valor de la celda [' + str(column) + ', ' + str(index_data) + '] es requerido porque la celda [' +
            str(possibly_data_name) + ', ' + str(index_data) + '] tiene un valor: ' + str(possibly_data))
  except:
    pass

# %% [markdown]
# - El pais financiador no puede ser Colombia: codigo 170

# %%
def validate_not_Colombia(data, index_data, dictionary, sheet, column):
  '''validates that the given data don't be 170'''
  try:
    if (str(data) == str(170)):
      dictionary[sheet][column].append(     # Se almacena el hallazgo
            'el valor de la celda [' + str(column) + ', ' + str(index_data) + '] no puede ser 170 porque el país financiador no puede ser colombia')
  except:
    pass

# %% [markdown]
# - El teléfono debe tener una longitud mayor o igual a 7

# %%
def validate_phone(data, index_data, dictionary, sheet, column):
  '''validates that the length of data be equal or longer than 7'''
  try:
    if (len(str(data)) < 7):
      dictionary[sheet][column].append(
          'la longitud de la celda [' + str(column) + ', ' + str(index_data) +
          '] es: ' + str(len(str(data))) + ' y debe ser mayor o igual a 7: ')
  except:
    pass

# %% [markdown]
# - El email debe estar bien estructurado. Revisa que tenga @

# %%
def val_email(data, index_data, dictionary, sheet, column):
  '''validates the email based in a default function'''
  try:
    if (validate_email(data)):
      pass
    else:
      dictionary[sheet][column].append('el email de la celda [' + str(column) + ', ' + str(index_data) + '] no es valido')
  except:
    dictionary[sheet][column].append('el email de la celda [' + str(column) + ', ' + str(index_data) + '] no es valido')

# %%
def start_up_all_functions(general_path, year_open_period):
  ''' run all the validations of all files of all folders '''
  running_11_1_CURSOS(general_path)     # this one doesn't required a year open period validation
  running_11_2_EDUCACION_CONTINUA(general_path, year_open_period)
  running_11_3_CONSULTORIA(general_path, year_open_period)
  running_11_4_EVENTO_CULTURAL(general_path, year_open_period)
  running_11_5_ACTIVIDAD_CULTURAL(general_path, year_open_period)
  running_11_6_SERVICIOS_DE_EXTENSION(general_path, year_open_period)
  running_11_7_PROYECTO_DE_EXTENSION(general_path, year_open_period)

# %% [markdown]
# # 11. EXTENSIÓN:

# %% [markdown]
# > # 11.1. **Cursos**

# %% [markdown]
# >> ### Validation functions of each column of the sheet:

# %% [markdown]
# > #### 'CURSOS'

# %%
def val_CURSO_codigo_curso(sheet, col_name, fields_report):
  sheet_CURSO_name = 'CURSO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CURSO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 20, fields_report, sheet_CURSO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CURSO_name, col_name)

# %%
def val_CURSO_nombre_curso(sheet, col_name, fields_report):
  sheet_CURSO_name = 'CURSO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CURSO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_CURSO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CURSO_name, col_name)

# %%
def val_CURSO_id_cine_campo_detallado (sheet, col_name, fields_report):
  sheet_CURSO_name = 'CURSO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CURSO_name, col_name)

    try:
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_CURSO_name, col_name)
    except:
      pass

    try:
      cell = int(cell)
      # Validación valores validos
      validate_values(cell, index_cell, 'valid_values_CURSOS.xlsx', 'CURSOS', 'ID_CINE_CAMPO_DETALLADO', fields_report, sheet_CURSO_name, col_name)
    except:
      pass

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CURSO_name, col_name)

# %%
def val_CURSO_es_extension (sheet, col_name, fields_report):
  sheet_CURSO_name = 'CURSO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CURSO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 1, fields_report, sheet_CURSO_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CURSOS.xlsx', 'CURSOS', 'ES_EXTENSION', fields_report, sheet_CURSO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CURSO_name, col_name)

# %%
def val_CURSO_activo(sheet, col_name, fields_report):
  sheet_CURSO_name = 'CURSO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CURSO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 1, fields_report, sheet_CURSO_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CURSOS.xlsx', 'CURSOS', 'ACTIVO', fields_report, sheet_CURSO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CURSO_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
def CURSO_report (doc_name,general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'CURSOS', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/CURSOS_revisados/Revision_CURSO_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'CURSO').to_excel(writer, 'CURSOS', index = False )    # add other sheet for the specific data of the courses
  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_CURSO(doc_name, general_path):

  fields_found_CURSO = []     # to store the sheets and fields that were reviewed
  fields_not_found_CURSO = []   # to store sheets and fields that were not found
  fields_report_CURSO ={    # dictionary to store the findings of each field
      'CURSO' : {
          'CODIGO_CURSO':[],
          'NOMBRE_CURSO':[],
          'ID_CINE_CAMPO_DETALLADO':[],
          'ES_EXTENSION':[],
          'ACTIVO':[]
      }
  }

  # sheet validation < CURSO >

  try:    # try to search, open and validate the sheet
    curso_sheet = pd.read_excel(general_path + '11.1. CURSOS/' + doc_name, sheet_name='CURSO')     # open excel
    fields_found_CURSO.append('CURSO')    # if found, stored

    validate_column('CODIGO_CURSO', fields_found_CURSO, fields_not_found_CURSO,
                    val_CURSO_codigo_curso(curso_sheet, 'CODIGO_CURSO', fields_report_CURSO))
    validate_column('NOMBRE_CURSO', fields_found_CURSO, fields_not_found_CURSO,
                    val_CURSO_nombre_curso(curso_sheet, 'NOMBRE_CURSO', fields_report_CURSO))
    validate_column('ID_CINE_CAMPO_DETALLADO', fields_found_CURSO, fields_not_found_CURSO,
                    val_CURSO_id_cine_campo_detallado(curso_sheet, 'ID_CINE_CAMPO_DETALLADO', fields_report_CURSO))
    validate_column('ES_EXTENSION', fields_found_CURSO, fields_not_found_CURSO,
                    val_CURSO_es_extension(curso_sheet, 'ES_EXTENSION', fields_report_CURSO))
    validate_column('ACTIVO', fields_found_CURSO, fields_not_found_CURSO,
                    val_CURSO_activo(curso_sheet, 'ACTIVO', fields_report_CURSO))

  except ValueError:
    fields_not_found_CURSO.append('CURSO')     # sheet < CURSO > not found

  CURSO_report(doc_name, general_path, fields_found_CURSO, fields_not_found_CURSO, fields_report_CURSO)     # Generates the excel document

# %% [markdown]
# >> ### loop through all the files in the folder '11.1 CURSOS'

# %%
def running_11_1_CURSOS(general_path):
  # accessing to folder '11.1. CURSOS'
  cursos_path = Path(general_path + '11.1. CURSOS/')
  for entry in cursos_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_CURSO(doc_name, general_path)    # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.2. **Educación continua**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# > #### 'EDUCACION_CONTINUA'

# %%
def val_EDU_CONT_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EDU_CONT_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period, fields_report,sheet_EDU_CONT_name, col_name)

# %%
def val_EDU_CONT_semestre(sheet, col_name, fields_report):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EDU_CONT_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCACION_CONTINUA', 'SEMESTRE', fields_report, sheet_EDU_CONT_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)

# %%
def val_EDU_CONT_codigo_curso(sheet, col_name, fields_report):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EDU_CONT_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 20, fields_report, sheet_EDU_CONT_name, col_name)

    # Validación de valores validos
    # Para este campo no se requieren valores validos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)

# %%
def val_EDU_CONT_num_horas(sheet, col_name, fields_report):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 5, fields_report, sheet_EDU_CONT_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Para este campo no se requieren valores validos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)

# %%
def val_EDU_CONT_id_tipo_curso_extension (sheet, col_name, fields_report):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_EDU_CONT_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCACION_CONTINUA', 'ID_TIPO_CURSO_EXTENSION', fields_report, sheet_EDU_CONT_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)

# %%
def val_EDU_CONT_valor_curso (sheet, col_name, fields_report):
  sheet_EDU_CONT_name = 'EDUCACION_CONTINUA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 9, fields_report, sheet_EDU_CONT_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Para este campo no se requieren valores validos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EDU_CONT_name, col_name)

# %% [markdown]
# > #### 'EDUCACION_CONTINUA_DOCENTES'

# %%
def val_EDU_CONT_DOCENTES_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EDU_CONT_DOCENTES_name = 'EDUCACION_CONTINUA_DOCENTES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

# %%
def val_EDU_CONT_DOCENTES_semestre(sheet, col_name, fields_report):
  sheet_EDU_CONT_DOCENTES_name = 'EDUCACION_CONTINUA_DOCENTES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCACION_CONTINUA_DOCENTES', 'SEMESTRE', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

# %%
def val_EDU_CONT_DOCENTES_codigo_curso(sheet, col_name, fields_report):
  sheet_EDU_CONT_DOCENTES_name = 'EDUCACION_CONTINUA_DOCENTES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 20, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

# %%
def val_EDU_CONT_DOCENTES_id_tipo_documento(sheet, col_name, fields_report):
  sheet_EDU_CONT_DOCENTES_name = 'EDUCACION_CONTINUA_DOCENTES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 2, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCACION_CONTINUA_DOCENTES', 'ID_TIPO_DOCUMENTO', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

# %%
def val_EDU_CONT_DOCENTES_num_documento(sheet, col_name, fields_report):
  sheet_EDU_CONT_DOCENTES_name = 'EDUCACION_CONTINUA_DOCENTES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_DOCENTES_name, col_name)

# %% [markdown]
# > #### 'EDUCAC_CONTINUA_BENEFICIARIOS'

# %%
def val_EDU_CONT_BENEFICIARIOS_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EDU_CONT_BENEFICIARIOS_name = 'EDUCAC_CONTINUA_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

# %%
def val_EDU_CONT_BENEFICIARIOS_semestre(sheet, col_name, fields_report):
  sheet_EDU_CONT_BENEFICIARIOS_name = 'EDUCAC_CONTINUA_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCAC_CONTINUA_BENEFICIARIOS', 'SEMESTRE', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

# %%
def val_EDU_CONT_BENEFICIARIOS_codigo_curso(sheet, col_name, fields_report):
  sheet_EDU_CONT_BENEFICIARIOS_name = 'EDUCAC_CONTINUA_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 20, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

# %%
def val_EDU_CONT_BENEFICIARIOS_id_tipo_benef_extension(sheet, col_name, fields_report):
  sheet_EDU_CONT_BENEFICIARIOS_name = 'EDUCAC_CONTINUA_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EDUCACION_CONTINUA.xlsx', 'EDUCAC_CONTINUA_BENEFICIARIOS', 'ID_TIPO_BENEF_EXTENSION', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

# %%
def val_EDU_CONT_BENEFICIARIOS_cantidad_beneficiarios(sheet, col_name, fields_report):
  sheet_EDU_CONT_BENEFICIARIOS_name = 'EDUCAC_CONTINUA_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EDU_CONT_BENEFICIARIOS_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
## generar reporte
def EDU_CONTINUA_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'EDUCACION CONTINUA', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/EDUCACIÓN_CONTINUA_revisados/Revision_EDU_CONTINUA_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'EDUCACION_CONTINUA').to_excel(writer, 'EDUCACION_CONTINUA', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'EDUCACION_CONTINUA_DOCENTES').to_excel(writer, 'EDUCACION_CONTINUA_DOCENTES', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'EDUCAC_CONTINUA_BENEFICIARIOS').to_excel(writer, 'EDUCAC_CONTINUA_BENEFICIARIOS', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_EDU_CONTINUA(doc_name, general_path, year_open_period):
  fields_found_EDU_CONTINUA = []     # to store the sheets and fields that were reviewed
  fields_not_found_EDU_CONTINUA = []   # to store sheets and fields that were not found
  fields_report_EDU_CONTINUA ={    # dictionary to store the findings of each field
      'EDUCACION_CONTINUA' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_CURSO':[],
          'NUM_HORAS':[],
          'ID_TIPO_CURSO_EXTENSION':[],
          'VALOR_CURSO':[],
      },
      'EDUCACION_CONTINUA_DOCENTES' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_CURSO':[],
          'ID_TIPO_DOCUMENTO':[],
          'NUM_DOCUMENTO':[],
      },
      'EDUCAC_CONTINUA_BENEFICIARIOS' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_CURSO':[],
          'ID_TIPO_BENEF_EXTENSION':[],
          'CANTIDAD_BENEFICIARIOS':[],
      }
  }
  # sheet validation < EDUCACION_CONTINUA >
  try:    # try to search, open and validate the sheet 'EDUCACION_CONTINUA'

    educacion_continua_sheet = pd.read_excel(general_path + '11.2. EDUCACIÓN CONTINUA/' + doc_name, sheet_name='EDUCACION_CONTINUA')     # open excel
    fields_found_EDU_CONTINUA.append('EDUCACION_CONTINUA')    # if found, stored

    validate_column('AÑO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_ano(educacion_continua_sheet, 'AÑO', fields_report_EDU_CONTINUA, year_open_period))
    validate_column('SEMESTRE', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_semestre(educacion_continua_sheet, 'SEMESTRE', fields_report_EDU_CONTINUA))
    validate_column('CODIGO_CURSO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_codigo_curso(educacion_continua_sheet, 'CODIGO_CURSO', fields_report_EDU_CONTINUA))
    validate_column('NUM_HORAS', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_num_horas(educacion_continua_sheet, 'NUM_HORAS', fields_report_EDU_CONTINUA))
    validate_column('ID_TIPO_CURSO_EXTENSION', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_id_tipo_curso_extension(educacion_continua_sheet, 'ID_TIPO_CURSO_EXTENSION', fields_report_EDU_CONTINUA))
    validate_column('VALOR_CURSO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_valor_curso(educacion_continua_sheet, 'VALOR_CURSO', fields_report_EDU_CONTINUA))

  except ValueError:
    fields_not_found_EDU_CONTINUA.append('EDUCACION_CONTINUA')     # sheet < EDUCACION_CONTINUA > not found

  # sheet validation < EDUCACION_CONTINUA_DOCENTES >
  try:    # try to search, open and validate the sheet 'EDUCACION_CONTINUA_DOCENTES'

    educacion_continua_docentes_sheet = pd.read_excel(general_path + '11.2. EDUCACIÓN CONTINUA/' + doc_name, sheet_name='EDUCACION_CONTINUA_DOCENTES')     # open excel
    fields_found_EDU_CONTINUA.append('EDUCACION_CONTINUA_DOCENTES')    # if found, stored

    validate_column('AÑO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_DOCENTES_ano(educacion_continua_docentes_sheet, 'AÑO', fields_report_EDU_CONTINUA, year_open_period))
    validate_column('SEMESTRE', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_DOCENTES_semestre(educacion_continua_docentes_sheet, 'SEMESTRE', fields_report_EDU_CONTINUA))
    validate_column('CODIGO_CURSO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_DOCENTES_codigo_curso(educacion_continua_docentes_sheet, 'CODIGO_CURSO', fields_report_EDU_CONTINUA))
    validate_column('ID_TIPO_DOCUMENTO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_DOCENTES_id_tipo_documento(educacion_continua_docentes_sheet, 'ID_TIPO_DOCUMENTO', fields_report_EDU_CONTINUA))
    validate_column('NUM_DOCUMENTO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_DOCENTES_num_documento(educacion_continua_docentes_sheet, 'NUM_DOCUMENTO', fields_report_EDU_CONTINUA))

  except ValueError:
    fields_not_found_EDU_CONTINUA.append('EDUCACION_CONTINUA_DOCENTES')     # sheet < EDUCACION_CONTINUA_DOCENTES > not found

  # sheet validation < EDUCAC_CONTINUA_BENEFICIARIOS >
  try:    # try to search, open and validate the sheet 'EDUCAC_CONTINUA_BENEFICIARIOS'

    educac_continua_beneficiarios_sheet = pd.read_excel(general_path + '11.2. EDUCACIÓN CONTINUA/' + doc_name, sheet_name='EDUCAC_CONTINUA_BENEFICIARIOS')     # open excel
    fields_found_EDU_CONTINUA.append('EDUCAC_CONTINUA_BENEFICIARIOS')    # if found, stored

    validate_column('AÑO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_BENEFICIARIOS_ano(educac_continua_beneficiarios_sheet, 'AÑO', fields_report_EDU_CONTINUA, year_open_period))
    validate_column('SEMESTRE', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_BENEFICIARIOS_semestre(educac_continua_beneficiarios_sheet, 'SEMESTRE', fields_report_EDU_CONTINUA))
    validate_column('CODIGO_CURSO', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_BENEFICIARIOS_codigo_curso(educac_continua_beneficiarios_sheet, 'CODIGO_CURSO', fields_report_EDU_CONTINUA))
    validate_column('ID_TIPO_BENEF_EXTENSION', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_BENEFICIARIOS_id_tipo_benef_extension(educac_continua_beneficiarios_sheet, 'ID_TIPO_BENEF_EXTENSION', fields_report_EDU_CONTINUA))
    validate_column('CANTIDAD_BENEFICIARIOS', fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA,
                    val_EDU_CONT_BENEFICIARIOS_cantidad_beneficiarios(educac_continua_beneficiarios_sheet, 'CANTIDAD_BENEFICIARIOS', fields_report_EDU_CONTINUA))

  except ValueError:
    fields_not_found_EDU_CONTINUA.append('EDUCAC_CONTINUA_BENEFICIARIOS')     # sheet < EDUCAC_CONTINUA_BENEFICIARIOS > not found

  EDU_CONTINUA_report(doc_name, general_path, fields_found_EDU_CONTINUA, fields_not_found_EDU_CONTINUA, fields_report_EDU_CONTINUA)

# %% [markdown]
# >> ### loop through all the files in the folder '11.2 EDUCACIÓN CONTINUA'

# %%
def running_11_2_EDUCACION_CONTINUA(general_path, year_open_period):
  # educación continua files
  edu_continua_path = Path(general_path + '11.2. EDUCACIÓN CONTINUA/')
  for entry in edu_continua_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_EDU_CONTINUA(doc_name, general_path, year_open_period)     # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.3. **Consultoría**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# #### 'CONSULTORIA'

# %%
def val_CONSULTORIA_ano(sheet, col_name, fields_report, year_open_period):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_semestre(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'SEMESTRE', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_codigo_consultoria(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_descripcion_consultoria(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_cine_campo_detallado(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_CINE_CAMPO_DETALLADO', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_nombre_entidad(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_sector_consultoria(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_SECTOR_CONSULTORIA', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_valor(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_fecha_inicio(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_date_80_years_before(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_fecha_final(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específicos

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_final_date_older_initial_date(cell, index_cell, sheet, 'FECHA_INICIO', fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_fuente_nacional(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_FUENTE_NACIONAL', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_CONSULTORIA_vlr_financiacion_nacional(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_NACIONAL', cell, index_cell, sheet, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_nombre_institucion(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumeric >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_CONSULTORIA_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_NACIONAL', cell, index_cell, sheet, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_pais_financiador(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_PAIS_FINANCIADOR', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_not_Colombia(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_fuente_internacional(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_FUENTE_INTERNACIONAL', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_CONSULTORIA_vlr_financiacion_internacional(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_CONSULTORIA_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %%
def val_CONSULTORIA_id_cine_campo_detallado(sheet, col_name, fields_report):
  sheet_CONSULTORIA_name = 'CONSULTORIA'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULTORIA_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_CONSULTORIA_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA', 'ID_CINE_CAMPO_DETALLADO', fields_report, sheet_CONSULTORIA_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULTORIA_name, col_name)

# %% [markdown]
# #### 'CONSULTORIA_REC_HUMANO'

# %%
def val_CONSULT_REC_HUM_ano(sheet, col_name, fields_report, year_open_period):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_CONSULT_REC_HUM_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %%
def val_CONSULT_REC_HUM_semestre(sheet, col_name, fields_report):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_CONSULT_REC_HUM_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA_REC_HUMANO', 'SEMESTRE', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %%
def val_CONSULT_REC_HUM_codigo_consultoria(sheet, col_name, fields_report):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %%
def val_CONSULT_REC_HUM_id_tipo_documento(sheet, col_name, fields_report):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 2, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA_REC_HUMANO', 'ID_TIPO_DOCUMENTO', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %%
def val_CONSULT_REC_HUM_num_documento(sheet, col_name, fields_report):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %%
def val_CONSULT_REC_HUM_id_maximo_nivel_estudio(sheet, col_name, fields_report):
  sheet_CONSULT_REC_HUM_name = 'CONSULTORIA_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    try:
      cell = int(cell)
      # Validación longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_CONSULT_REC_HUM_name, col_name)
    except:
      pass

    # Validación valores validos
    validate_values(cell, index_cell, 'valid_values_CONSULTORÍA.xlsx', 'CONSULTORIA_REC_HUMANO', 'ID_MAXIMO_NIVEL_ESTUDIO', fields_report, sheet_CONSULT_REC_HUM_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_CONSULT_REC_HUM_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
## generar reporte
def CONSULTORIA_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'CONSULTORÍA', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/CONSULTORÍA_revisados/Revision_CONSULTORIA_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'CONSULTORIA').to_excel(writer, 'CONSULTORIA', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'CONSULTORIA_REC_HUMANO').to_excel(writer, 'CONSULTORIA_REC_HUMANO', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_CONSULTORIA(doc_name, general_path, year_open_period):
  fields_found_CONSULTORIA = []     # to store the sheets and fields that were reviewed
  fields_not_found_CONSULTORIA = []   # to store sheets and fields that were not found
  fields_report_CONSULTORIA = {    # dictionary to store the findings of each field
      'CONSULTORIA' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_CONSULTORIA':[],
          'DESCRIPCION_CONSULTORIA':[],
          'ID_CINE_CAMPO_DETALLADO':[],
          'NOMBRE_ENTIDAD':[],
          'ID_SECTOR_CONSULTORIA':[],
          'VALOR':[],
          'FECHA_INICIO':[],
          'FECHA_FINAL':[],
          'ID_FUENTE_NACIONAL':[],
          'VLR_FINANCIACION_NACIONAL':[],
          'NOMBRE_INSTITUCION':[],
          'ID_PAIS_FINANCIADOR':[],
          'ID_FUENTE_INTERNACIONAL':[],
          'VLR_FINANCIACION_INTERNACIONAL':[],
          'ID_CINE_CAMPO_DETALLADO':[]
      },
      'CONSULTORIA_REC_HUMANO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_CONSULTORIA':[],
          'ID_TIPO_DOCUMENTO':[],
          'NUM_DOCUMENTO':[],
          'ID_MAXIMO_NIVEL_ESTUDIO':[]
      }
  }

  # sheet validation < CONSULTORIA >
  try:    # try to search, open and validate the sheet 'CONSULTORIA'

    consultoria_sheet = pd.read_excel(general_path + '11.3. CONSULTORÍA/' + doc_name, sheet_name='CONSULTORIA')     # open excel
    fields_found_CONSULTORIA.append('CONSULTORIA')    # if found, stored

    validate_column('AÑO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_ano(consultoria_sheet, 'AÑO', fields_report_CONSULTORIA, year_open_period))
    validate_column('SEMESTRE', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_semestre(consultoria_sheet, 'SEMESTRE', fields_report_CONSULTORIA))
    validate_column('CODIGO_CONSULTORIA', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_codigo_consultoria(consultoria_sheet, 'CODIGO_CONSULTORIA', fields_report_CONSULTORIA))
    validate_column('DESCRIPCION_CONSULTORIA', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_descripcion_consultoria(consultoria_sheet, 'DESCRIPCION_CONSULTORIA', fields_report_CONSULTORIA))
    validate_column('ID_CINE_CAMPO_DETALLADO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_cine_campo_detallado(consultoria_sheet, 'ID_CINE_CAMPO_DETALLADO', fields_report_CONSULTORIA))
    validate_column('NOMBRE_ENTIDAD', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_nombre_entidad(consultoria_sheet, 'NOMBRE_ENTIDAD', fields_report_CONSULTORIA))
    validate_column('ID_SECTOR_CONSULTORIA', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_sector_consultoria(consultoria_sheet, 'ID_SECTOR_CONSULTORIA', fields_report_CONSULTORIA))
    validate_column('VALOR', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_valor(consultoria_sheet, 'VALOR', fields_report_CONSULTORIA))
    validate_column('FECHA_INICIO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_fecha_inicio(consultoria_sheet, 'FECHA_INICIO', fields_report_CONSULTORIA))
    validate_column('FECHA_FINAL', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_fecha_final(consultoria_sheet, 'FECHA_FINAL', fields_report_CONSULTORIA))
    validate_column('ID_FUENTE_NACIONAL', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_fuente_nacional(consultoria_sheet, 'ID_FUENTE_NACIONAL', fields_report_CONSULTORIA))
    validate_column('VLR_FINANCIACION_NACIONAL', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_vlr_financiacion_nacional(consultoria_sheet, 'VLR_FINANCIACION_NACIONAL', fields_report_CONSULTORIA))
    validate_column('NOMBRE_INSTITUCION', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_nombre_institucion(consultoria_sheet, 'NOMBRE_INSTITUCION', fields_report_CONSULTORIA))
    validate_column('ID_PAIS_FINANCIADOR', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_pais_financiador(consultoria_sheet, 'ID_PAIS_FINANCIADOR', fields_report_CONSULTORIA))
    validate_column('ID_FUENTE_INTERNACIONAL', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_fuente_internacional(consultoria_sheet, 'ID_FUENTE_INTERNACIONAL', fields_report_CONSULTORIA))
    validate_column('VLR_FINANCIACION_INTERNACIONAL', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_vlr_financiacion_internacional(consultoria_sheet, 'VLR_FINANCIACION_INTERNACIONAL', fields_report_CONSULTORIA))
    validate_column('ID_CINE_CAMPO_DETALLADO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULTORIA_id_cine_campo_detallado(consultoria_sheet, 'ID_CINE_CAMPO_DETALLADO', fields_report_CONSULTORIA))

  except ValueError:
    fields_not_found_CONSULTORIA.append('CONSULTORIA')     # sheet < CONSULTORIA > not found

  # sheet validation < CONSULTORIA_REC_HUMANO >
  try:    # try to search, open and validate the sheet 'CONSULTORIA_REC_HUMANO'

    consultoria_rec_humano_sheet = pd.read_excel(general_path + '11.3. CONSULTORÍA/' + doc_name, sheet_name='CONSULTORIA_REC_HUMANO')     # open excel
    fields_found_CONSULTORIA.append('CONSULTORIA_REC_HUMANO')    # if found, stored

    validate_column('AÑO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_ano(consultoria_rec_humano_sheet, 'AÑO', fields_report_CONSULTORIA, year_open_period))
    validate_column('SEMESTRE', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_semestre(consultoria_rec_humano_sheet, 'SEMESTRE', fields_report_CONSULTORIA))
    validate_column('CODIGO_CONSULTORIA', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_codigo_consultoria(consultoria_rec_humano_sheet, 'CODIGO_CONSULTORIA', fields_report_CONSULTORIA))
    validate_column('ID_TIPO_DOCUMENTO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_id_tipo_documento(consultoria_rec_humano_sheet, 'ID_TIPO_DOCUMENTO', fields_report_CONSULTORIA))
    validate_column('NUM_DOCUMENTO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_num_documento(consultoria_rec_humano_sheet, 'NUM_DOCUMENTO', fields_report_CONSULTORIA))
    validate_column('ID_MAXIMO_NIVEL_ESTUDIO', fields_found_CONSULTORIA, fields_not_found_CONSULTORIA,
                    val_CONSULT_REC_HUM_id_maximo_nivel_estudio(consultoria_rec_humano_sheet, 'ID_MAXIMO_NIVEL_ESTUDIO', fields_report_CONSULTORIA))

  except ValueError:
    fields_not_found_CONSULTORIA.append('CONSULTORIA_REC_HUMANO')     # sheet < CONSULTORIA_REC_HUMANO > not found

  CONSULTORIA_report(doc_name, general_path, fields_found_CONSULTORIA, fields_not_found_CONSULTORIA, fields_report_CONSULTORIA)

# %% [markdown]
# >> ### loop through all the files in the folder '11.3 CONSULTORÍA'

# %%
def running_11_3_CONSULTORIA(general_path, year_open_period):
  consultoria_path = Path(general_path + '11.3. CONSULTORÍA/')
  for entry in consultoria_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_CONSULTORIA(doc_name, general_path, year_open_period)    # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.4. **Evento cultural**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# #### 'EVENTO_CULTURAL'

# %%
def val_EVENTO_CULTURAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_semestre(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULTURAL', 'SEMESTRE', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_codigo_evento(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_descripcion_evento(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_fecha_inicio(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    # Esta validación no requiere de una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    validate_date_80_years_before(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_fecha_final(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    # Esta validación no requiere de una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_final_date_older_initial_date(cell, index_cell, sheet, 'FECHA_INICIO', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_id_fuente_nacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULTURAL', 'ID_FUENTE_NACIONAL', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Otras validaciones
    # Esta validación no requiere validaciones específicas

# %%
def val_EVENTO_CULTURAL_vlr_financiacion_nacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_NACIONAL', cell, index_cell, sheet, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_nombre_institucion(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alphanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_id_pais_financiador(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULTURAL', 'ID_PAIS_FINANCIADOR', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    validate_not_Colombia(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %%
def val_EVENTO_CULTURAL_id_fuente_internacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULTURAL', 'ID_FUENTE_INTERNACIONAL', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_EVENTO_CULTURAL_vlr_financiacion_internacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULTURAL_name = 'EVENTO_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_EVENTO_CULTURAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EVENTO_CULTURAL_name, col_name)

# %% [markdown]
# #### 'EVENTO_CULT_REC_HUMANO'

# %%
def val_EVENTO_CULT_REC_HUMANO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_semestre(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULT_REC_HUMANO', 'SEMESTRE', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_codigo_evento(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_id_tipo_documento(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 2, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULT_REC_HUMANO', 'ID_TIPO_DOCUMENTO', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_num_documento(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %%
def val_EVENTO_CULT_REC_HUMANO_dedicacion(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_REC_HUMANO_name = 'EVENTO_CULT_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Validación validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EVENTO_CULT_REC_HUMANO_name, col_name)

# %% [markdown]
# #### 'EVENTO_CULT_BENEFICIARIOS'

# %%
def val_EVENTO_CULT_BENEFICIARIOS_ano(sheet, col_name, fields_report, year_open_period):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de la valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_semestre(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULT_BENEFICIARIOS', 'SEMESTRE', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Validación validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_codigo_evento(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_id_tipo_beneficiario(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_EVENTO_CULTURAL.xlsx', 'EVENTO_CULT_BENEFICIARIOS', 'ID_TIPO_BENEFICIARIO', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_total_asistentes(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %%
def val_EVENTO_CULT_BENEFICIARIOS_valor_entrada(sheet, col_name, fields_report):
  sheet_EVENTO_CULT_BENEFICIARIOS_name = 'EVENTO_CULT_BENEFICIARIOS'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Validación validaciones
    validate_required(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_EVENTO_CULT_BENEFICIARIOS_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
def EVENTO_CULTURAL_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'EVENTO CULTURAL', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/EVENTO_CULTURAL_revisados/Revision_EVENTO_CULTURAL_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'EVENTO_CULTURAL').to_excel(writer, 'EVENTO_CULTURAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'EVENTO_CULT_REC_HUMANO').to_excel(writer, 'EVENTO_CULT_REC_HUMANO', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'EVENTO_CULT_BENEFICIARIOS').to_excel(writer, 'EVENTO_CULT_BENEFICIARIOS', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_EVENTO_CULTURAL(doc_name, general_path, year_open_period):
  fields_found_EVENTO_CULTURAL = []     # to store the sheets and fields that were reviewed
  fields_not_found_EVENTO_CULTURAL = []   # to store sheets and fields that were not found
  fields_report_EVENTO_CULTURAL = {    # dictionary to store the findings of each field
      'EVENTO_CULTURAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_EVENTO':[],
          'DESCRIPCION_EVENTO':[],
          'FECHA_INICIO':[],
          'FECHA_FINAL':[],
          'ID_FUENTE_NACIONAL':[],
          'VLR_FINANCIACION_NACIONAL':[],
          'NOMBRE_INSTITUCION':[],
          'ID_PAIS_FINANCIADOR':[],
          'ID_FUENTE_INTERNACIONAL':[],
          'VLR_FINANCIACION_INTERNACIONAL':[]
      },
      'EVENTO_CULT_REC_HUMANO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_EVENTO':[],
          'ID_TIPO_DOCUMENTO':[],
          'NUM_DOCUMENTO':[],
          'DEDICACION':[]
      },
      'EVENTO_CULT_BENEFICIARIOS' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_EVENTO':[],
          'ID_TIPO_BENEFICIARIO':[],
          'TOTAL_ASISTENTES':[],
          'VALOR_ENTRADA':[]
      }
  }

  # sheet validation < EVENTO_CULTURAL >
  try:    # try to search, open and validate the sheet 'EVENTO_CULTURAL'

    evento_cultural_sheet = pd.read_excel(general_path + '11.4. EVENTO CULTURAL/' + doc_name, sheet_name='EVENTO_CULTURAL')     # open excel
    fields_found_EVENTO_CULTURAL.append('EVENTO_CULTURAL')    # if found, stored

    validate_column('AÑO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_ano(evento_cultural_sheet, 'AÑO', fields_report_EVENTO_CULTURAL, year_open_period))
    validate_column('SEMESTRE', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_semestre(evento_cultural_sheet, 'SEMESTRE', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_codigo_unidad_organizacional(evento_cultural_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_EVENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_codigo_evento(evento_cultural_sheet, 'CODIGO_EVENTO', fields_report_EVENTO_CULTURAL))
    validate_column('DESCRIPCION_EVENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_descripcion_evento(evento_cultural_sheet, 'DESCRIPCION_EVENTO', fields_report_EVENTO_CULTURAL))
    validate_column('FECHA_INICIO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_fecha_inicio(evento_cultural_sheet, 'FECHA_INICIO', fields_report_EVENTO_CULTURAL))
    validate_column('FECHA_FINAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_fecha_final(evento_cultural_sheet, 'FECHA_FINAL', fields_report_EVENTO_CULTURAL))
    validate_column('ID_FUENTE_NACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_id_fuente_nacional(evento_cultural_sheet, 'ID_FUENTE_NACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('VLR_FINANCIACION_NACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_vlr_financiacion_nacional(evento_cultural_sheet, 'VLR_FINANCIACION_NACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('NOMBRE_INSTITUCION', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_nombre_institucion(evento_cultural_sheet, 'NOMBRE_INSTITUCION', fields_report_EVENTO_CULTURAL))
    validate_column('ID_PAIS_FINANCIADOR', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_id_pais_financiador(evento_cultural_sheet, 'ID_PAIS_FINANCIADOR', fields_report_EVENTO_CULTURAL))
    validate_column('ID_FUENTE_INTERNACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_id_fuente_internacional(evento_cultural_sheet, 'ID_FUENTE_INTERNACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('VLR_FINANCIACION_INTERNACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULTURAL_vlr_financiacion_internacional(evento_cultural_sheet, 'VLR_FINANCIACION_INTERNACIONAL', fields_report_EVENTO_CULTURAL))

  except ValueError:
    fields_not_found_EVENTO_CULTURAL.append('EVENTO_CULTURAL')     # sheet < EVENTO_CULTURAL > not found

  # sheet validation < EVENTO_CULT_REC_HUMANO >
  try:    # try to search, open and validate the sheet 'EVENTO_CULT_REC_HUMANO'

    evento_cult_rec_humano_sheet = pd.read_excel(general_path + '11.4. EVENTO CULTURAL/' + doc_name, sheet_name='EVENTO_CULT_REC_HUMANO')     # open excel
    fields_found_EVENTO_CULTURAL.append('EVENTO_CULT_REC_HUMANO')    # # if found, stored

    validate_column('AÑO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_ano(evento_cult_rec_humano_sheet, 'AÑO', fields_report_EVENTO_CULTURAL, year_open_period))
    validate_column('SEMESTRE', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_semestre(evento_cult_rec_humano_sheet, 'SEMESTRE', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_codigo_unidad_organizacional(evento_cult_rec_humano_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_EVENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_codigo_evento(evento_cult_rec_humano_sheet, 'CODIGO_EVENTO', fields_report_EVENTO_CULTURAL))
    validate_column('ID_TIPO_DOCUMENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_id_tipo_documento(evento_cult_rec_humano_sheet, 'ID_TIPO_DOCUMENTO', fields_report_EVENTO_CULTURAL))
    validate_column('NUM_DOCUMENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_num_documento(evento_cult_rec_humano_sheet, 'NUM_DOCUMENTO', fields_report_EVENTO_CULTURAL))
    validate_column('DEDICACION', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_REC_HUMANO_dedicacion(evento_cult_rec_humano_sheet, 'DEDICACION', fields_report_EVENTO_CULTURAL))

  except ValueError:
    fields_not_found_EVENTO_CULTURAL.append('EVENTO_CULT_REC_HUMANO')     # sheet < EVENTO_CULT_REC_HUMANO > not found

  # sheet validation < EVENTO_CULT_BENEFICIARIOS >
  try:    # try to search, open and validate the sheet 'EVENTO_CULT_BENEFICIARIOS'

    evento_cult_beneficiarios_sheet = pd.read_excel(general_path + '11.4. EVENTO CULTURAL/' + doc_name, sheet_name='EVENTO_CULT_BENEFICIARIOS')     # open excel
    fields_found_EVENTO_CULTURAL.append('EVENTO_CULT_BENEFICIARIOS')    # if found, stored

    validate_column('AÑO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_ano(evento_cult_beneficiarios_sheet, 'AÑO', fields_report_EVENTO_CULTURAL, year_open_period))
    validate_column('SEMESTRE', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_semestre(evento_cult_beneficiarios_sheet, 'SEMESTRE', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_codigo_unidad_organizacional(evento_cult_beneficiarios_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_EVENTO_CULTURAL))
    validate_column('CODIGO_EVENTO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_codigo_evento(evento_cult_beneficiarios_sheet, 'CODIGO_EVENTO', fields_report_EVENTO_CULTURAL))
    validate_column('ID_TIPO_BENEFICIARIO', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_id_tipo_beneficiario(evento_cult_beneficiarios_sheet, 'ID_TIPO_BENEFICIARIO', fields_report_EVENTO_CULTURAL))
    validate_column('TOTAL_ASISTENTES', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_total_asistentes(evento_cult_beneficiarios_sheet, 'TOTAL_ASISTENTES', fields_report_EVENTO_CULTURAL))
    validate_column('VALOR_ENTRADA', fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL,
                    val_EVENTO_CULT_BENEFICIARIOS_valor_entrada(evento_cult_beneficiarios_sheet, 'VALOR_ENTRADA', fields_report_EVENTO_CULTURAL))

  except ValueError:
    fields_not_found_EVENTO_CULTURAL.append('EVENTO_CULT_BENEFICIARIOS')     # sheet < EVENTO_CULT_BENEFICIARIOS > not found

  EVENTO_CULTURAL_report(doc_name, general_path, fields_found_EVENTO_CULTURAL, fields_not_found_EVENTO_CULTURAL, fields_report_EVENTO_CULTURAL)

# %% [markdown]
# >> ### loop through all the files in the folder '11.4 EVENTO CULTURAL'

# %%
def running_11_4_EVENTO_CULTURAL(general_path, year_open_period):
  evento_cultural_path = Path(general_path + '11.4. EVENTO CULTURAL/')
  for entry in evento_cultural_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_EVENTO_CULTURAL(doc_name, general_path, year_open_period)      # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.5. **Actividad cultural**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# #### 'ACTIVIDAD_CULTURAL'

# %%
def val_ACTIVIDAD_CULTURAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_semestre(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACTIVIDAD_CULTURAL', 'SEMESTRE', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_codigo_actividad(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_descripcion_actividad(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_id_tipo_actividad_cultural(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACTIVIDAD_CULTURAL', 'ID_TIPO_ACTIVIDAD_CULTURAL', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_fecha_inicio(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    validate_date_80_years_before(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_fecha_final(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_final_date_older_initial_date(cell, index_cell, sheet, 'FECHA_INICIO', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_id_fuente_nacional(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACTIVIDAD_CULTURAL', 'ID_FUENTE_NACIONAL', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_ACTIVIDAD_CULTURAL_vlr_financiacion_nacional(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_NACIONAL', cell, index_cell, sheet, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_nombre_institucion(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_id_pais_financiador(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACTIVIDAD_CULTURAL', 'ID_PAIS_FINANCIADOR', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Validación validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    validate_not_Colombia(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %%
def val_ACTIVIDAD_CULTURAL_id_fuente_internacional(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACTIVIDAD_CULTURAL', 'ID_FUENTE_INTERNACIONAL', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_ACTIVIDAD_CULTURAL_vlr_financiacion_internacional(sheet, col_name, fields_report):
  sheet_ACTIVIDAD_CULTURAL_name = 'ACTIVIDAD_CULTURAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Validación validaciones
    validate_required_if('ID_FUENTE_INTERNACIONAL', cell, index_cell, sheet, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_ACTIVIDAD_CULTURAL_name, col_name)

# %% [markdown]
# #### 'ACT_CULTURAL_REC_HUMANO'

# %%
def val_ACT_CULTURAL_REC_HUMANO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_semestre(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACT_CULTURAL_REC_HUMANO', 'SEMESTRE', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_codigo_actividad(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_id_tipo_documento(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 2, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_ACTIVIDAD_CULTURAL.xlsx', 'ACT_CULTURAL_REC_HUMANO', 'ID_TIPO_DOCUMENTO', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_num_documento(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %%
def val_ACT_CULTURAL_REC_HUMANO_dedicacion(sheet, col_name, fields_report):
  sheet_ACT_CULTURAL_REC_HUMANO_name = 'ACT_CULTURAL_REC_HUMANO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

    try:
      cell = int(cell)
      # Validación longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)
    except:
      pass

    # Validación valores validos
    # Este campo no requiere valores específicos

    # Validación validaciones
    validate_required(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_ACT_CULTURAL_REC_HUMANO_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
def ACTIVIDAD_CULTURAL_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'ACTIVIDAD CULTURAL', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/ACTIVIDAD_CULTURAL_revisados/Revision_ACTIVIDAD_CULTURAL_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'ACTIVIDAD_CULTURAL').to_excel(writer, 'ACTIVIDAD_CULTURAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'ACT_CULTURAL_REC_HUMANO').to_excel(writer, 'ACT_CULTURAL_REC_HUMANO', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_ACTIVIDAD_CULTURAL(doc_name, general_path, year_open_period):
  fields_found_ACTIVIDAD_CULTURAL = []     # to store the sheets and fields that were reviewed
  fields_not_found_ACTIVIDAD_CULTURAL = []   # to store sheets and fields that were not found
  fields_report_ACTIVIDAD_CULTURAL = {    # dictionary to store the findings of each field
      'ACTIVIDAD_CULTURAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_ACTIVIDAD':[],
          'DESCRIPCION_ACTIVIDAD':[],
          'ID_TIPO_ACTIVIDAD_CULTURAL':[],
          'FECHA_INICIO':[],
          'FECHA_FINAL':[],
          'ID_FUENTE_NACIONAL':[],
          'VLR_FINANCIACION_NACIONAL':[],
          'NOMBRE_INSTITUCION':[],
          'ID_PAIS_FINANCIADOR':[],
          'ID_FUENTE_INTERNACIONAL':[],
          'VLR_FINANCIACION_INTERNACIONAL':[]
      },
      'ACT_CULTURAL_REC_HUMANO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_ACTIVIDAD':[],
          'ID_TIPO_DOCUMENTO':[],
          'NUM_DOCUMENTO':[],
          'DEDICACION':[]
      }
  }

  # sheet validation < ACTIVIDAD_CULTURAL >
  try:    # try to search, open and validate the sheet 'ACTIVIDAD_CULTURAL'

    actividad_cultural_sheet = pd.read_excel(general_path + '11.5. ACTIVIDAD CULTURAL/' + doc_name, sheet_name='ACTIVIDAD_CULTURAL')     # open excel
    fields_found_ACTIVIDAD_CULTURAL.append('ACTIVIDAD_CULTURAL')    # if found, stored

    validate_column('AÑO', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_ano(actividad_cultural_sheet, 'AÑO', fields_report_ACTIVIDAD_CULTURAL, year_open_period))
    validate_column('SEMESTRE', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_semestre(actividad_cultural_sheet, 'SEMESTRE', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_codigo_unidad_organizacional(actividad_cultural_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('CODIGO_ACTIVIDAD', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_codigo_actividad(actividad_cultural_sheet, 'CODIGO_ACTIVIDAD', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('DESCRIPCION_ACTIVIDAD', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_descripcion_actividad(actividad_cultural_sheet, 'DESCRIPCION_ACTIVIDAD', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('ID_TIPO_ACTIVIDAD_CULTURAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_id_tipo_actividad_cultural(actividad_cultural_sheet, 'ID_TIPO_ACTIVIDAD_CULTURAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('FECHA_INICIO', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_fecha_inicio(actividad_cultural_sheet, 'FECHA_INICIO', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('FECHA_FINAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_fecha_final(actividad_cultural_sheet, 'FECHA_FINAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('ID_FUENTE_NACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_id_fuente_nacional(actividad_cultural_sheet, 'ID_FUENTE_NACIONAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('VLR_FINANCIACION_NACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_vlr_financiacion_nacional(actividad_cultural_sheet, 'VLR_FINANCIACION_NACIONAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('NOMBRE_INSTITUCION', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_nombre_institucion(actividad_cultural_sheet, 'NOMBRE_INSTITUCION', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('ID_PAIS_FINANCIADOR', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_id_pais_financiador(actividad_cultural_sheet, 'ID_PAIS_FINANCIADOR', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('ID_FUENTE_INTERNACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_id_fuente_internacional(actividad_cultural_sheet, 'ID_FUENTE_INTERNACIONAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('VLR_FINANCIACION_INTERNACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACTIVIDAD_CULTURAL_vlr_financiacion_internacional(actividad_cultural_sheet, 'VLR_FINANCIACION_INTERNACIONAL', fields_report_ACTIVIDAD_CULTURAL))

  except ValueError:
    fields_not_found_ACTIVIDAD_CULTURAL.append('ACTIVIDAD_CULTURAL')     # sheet < ACTIVIDAD_CULTURAL > not found

  # sheet validation < ACT_CULTURAL_REC_HUMANO >
  try:    # try to search, open and validate the sheet 'ACT_CULTURAL_REC_HUMANO'

    act_cultural_rec_humano_sheet = pd.read_excel(general_path + '11.5. ACTIVIDAD CULTURAL/' + doc_name, sheet_name='ACT_CULTURAL_REC_HUMANO')     # open excel
    fields_found_ACTIVIDAD_CULTURAL.append('ACT_CULTURAL_REC_HUMANO')    # if found, stored

    validate_column('AÑO', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_ano(act_cultural_rec_humano_sheet, 'AÑO', fields_report_ACTIVIDAD_CULTURAL, year_open_period))
    validate_column('SEMESTRE', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_semestre(act_cultural_rec_humano_sheet, 'SEMESTRE', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_codigo_unidad_organizacional(act_cultural_rec_humano_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('CODIGO_ACTIVIDAD', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_codigo_actividad(act_cultural_rec_humano_sheet, 'CODIGO_ACTIVIDAD', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('ID_TIPO_DOCUMENTO', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_id_tipo_documento(act_cultural_rec_humano_sheet, 'ID_TIPO_DOCUMENTO', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('NUM_DOCUMENTO', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_num_documento(act_cultural_rec_humano_sheet, 'NUM_DOCUMENTO', fields_report_ACTIVIDAD_CULTURAL))
    validate_column('DEDICACION', fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL,
                    val_ACT_CULTURAL_REC_HUMANO_dedicacion(act_cultural_rec_humano_sheet, 'DEDICACION', fields_report_ACTIVIDAD_CULTURAL))

  except ValueError:
    fields_not_found_ACTIVIDAD_CULTURAL.append('ACT_CULTURAL_REC_HUMANO')     # sheet < ACT_CULTURAL_REC_HUMANO > not found


  ACTIVIDAD_CULTURAL_report(doc_name, general_path, fields_found_ACTIVIDAD_CULTURAL, fields_not_found_ACTIVIDAD_CULTURAL, fields_report_ACTIVIDAD_CULTURAL)

# %% [markdown]
# >> ### loop through all the files in the folder '11.5 ACTIVIDAD CULTURAL'

# %%
def running_11_5_ACTIVIDAD_CULTURAL(general_path, year_open_period):
  actividad_cultural_path = Path(general_path + '11.5. ACTIVIDAD CULTURAL/')
  for entry in actividad_cultural_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_ACTIVIDAD_CULTURAL(doc_name, general_path, year_open_period)     # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.6. **Servicios de extensión**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# #### 'SERVICIOS_EXTENSION'

# %%
def val_SERVICIOS_EXTENSION_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_semestre(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERVICIOS_EXTENSION', 'SEMESTRE', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_nombre_servicio(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 400, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_descripcion_servicio(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 250, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_SERVICIOS_EXTENSION_valor_servicio(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_id_area_extension(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERVICIOS_EXTENSION', 'ID_AREA_EXTENSION', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_fecha_inicio(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    validate_date_80_years_before(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_fecha_final(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < fecha >
    validate_type(cell, index_cell, 'date', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_final_date_older_initial_date(cell, index_cell, sheet, 'FECHA_INICIO', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_nombre_contacto(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_apellido_contacto(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_telefono_contacto(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    validate_phone(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_email_contacto(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)
    val_email(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_tiene_costo(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 1, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERVICIOS_EXTENSION', 'TIENE_COSTO', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %%
def val_SERVICIOS_EXTENSION_criterio_elegibilidad(sheet, col_name, fields_report):
  sheet_SERVICIOS_EXTENSION_name = 'SERVICIOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERVICIOS_EXTENSION_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_AREA_TRABAJO'

# %%
def val_SERV_EXT_AREA_TRABAJO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_AREA_TRABAJO_name = 'SERV_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_SERV_EXT_AREA_TRABAJO_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_AREA_TRABAJO_name = 'SERV_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_AREA_TRABAJO', 'SEMESTRE', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_SERV_EXT_AREA_TRABAJO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_AREA_TRABAJO_name = 'SERV_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_SERV_EXT_AREA_TRABAJO_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_AREA_TRABAJO_name = 'SERV_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_SERV_EXT_AREA_TRABAJO_id_area_trabajo(sheet, col_name, fields_report):
  sheet_SERV_EXT_AREA_TRABAJO_name = 'SERV_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_AREA_TRABAJO', 'ID_AREA_TRABAJO', fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_AREA_TRABAJO_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_CICLO_VITAL'

# %%
def val_SERV_EXT_CICLO_VITAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_CICLO_VITAL_name = 'SERV_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

# %%
def val_SERV_EXT_CICLO_VITAL_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_CICLO_VITAL_name = 'SERV_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_CICLO_VITAL', 'SEMESTRE', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

# %%
def val_SERV_EXT_CICLO_VITAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_CICLO_VITAL_name = 'SERV_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

# %%
def val_SERV_EXT_CICLO_VITAL_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_CICLO_VITAL_name = 'SERV_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

# %%
def val_SERV_EXT_CICLO_VITAL_id_ciclo_vital(sheet, col_name, fields_report):
  sheet_SERV_EXT_CICLO_VITAL_name = 'SERV_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_CICLO_VITAL', 'ID_CICLO_VITAL', fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_CICLO_VITAL_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_ENTIDAD_NACIONAL'

# %%
def val_SERV_EXT_ENTIDAD_NACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_ENTIDAD_NACIONAL_name = 'SERV_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_ENTIDAD_NACIONAL_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_ENTIDAD_NACIONAL_name = 'SERV_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_ENTIDAD_NACIONAL', 'SEMESTRE', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_ENTIDAD_NACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_ENTIDAD_NACIONAL_name = 'SERV_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_ENTIDAD_NACIONAL_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_ENTIDAD_NACIONAL_name = 'SERV_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_ENTIDAD_NACIONAL_id_entidad_nacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_ENTIDAD_NACIONAL_name = 'SERV_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_ENTIDAD_NACIONAL', 'ID_ENTIDAD_NACIONAL', fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_ENTIDAD_NACIONAL_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_FUENTE_NACIONAL'

# %%
def val_SERV_EXT_FUENTE_NACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_NACIONAL_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_FUENTE_NACIONAL', 'SEMESTRE', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_NACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_NACIONAL_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_NACIONAL_id_fuente_nacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_FUENTE_NACIONAL', 'ID_FUENTE_NACIONAL', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_NACIONAL_valor_financiacion(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_NACIONAL_name = 'SERV_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_NACIONAL_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_FUENTE_INTERNACIONAL'

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_FUENTE_INTERNACIONAL', 'SEMESTRE', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_nombre_institucion(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_id_pais_financiador(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_FUENTE_INTERNACIONAL', 'ID_PAIS_FINANCIADOR', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_not_Colombia(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_id_fuente_internacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_FUENTE_INTERNACIONAL', 'ID_FUENTE_INTERNACIONAL', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_SERV_EXT_FUENTE_INTERNACIONAL_valor_financiacion(sheet, col_name, fields_report):
  sheet_SERV_EXT_FUENTE_INTERNACIONAL_name = 'SERV_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERV_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_OTRAS_ENTIDADES'  [pag 155]

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_OTRAS_ENTIDADES', 'SEMESTRE', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_nombre_entidad(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_id_pais_entidad(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_OTRAS_ENTIDADES', 'ID_PAIS_ENTIDAD', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_SERV_EXT_OTRAS_ENTIDADES_id_sector_entidad(sheet, col_name, fields_report):
  sheet_SERV_EXT_OTRAS_ENTIDADES_name = 'SERV_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_OTRAS_ENTIDADES', 'ID_SECTOR_ENTIDAD', fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_OTRAS_ENTIDADES_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_POBL_CONDICION'

# %%
def val_SERV_EXT_POBL_CONDICION_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %%
def val_SERV_EXT_POBL_CONDICION_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_POBL_CONDICION', 'SEMESTRE', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %%
def val_SERV_EXT_POBL_CONDICION_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %%
def val_SERV_EXT_POBL_CONDICION_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %%
def val_SERV_EXT_POBL_CONDICION_id_poblacion_por_condicion(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_POBL_CONDICION', 'ID_POBLACION_POR_CONDICION', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %%
def val_SERV_EXT_POBL_CONDICION_cantidad(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_CONDICION_name = 'SERV_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_CONDICION_name, col_name)

# %% [markdown]
# #### 'SERV_EXT_POBL_GRUPO'

# %%
def val_SERV_EXT_POBL_GRUPO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %%
def val_SERV_EXT_POBL_GRUPO_semestre(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_POBL_GRUPO', 'SEMESTRE', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %%
def val_SERV_EXT_POBL_GRUPO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %%
def val_SERV_EXT_POBL_GRUPO_codigo_servicio(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %%
def val_SERV_EXT_POBL_GRUPO_id_poblacion_por_grupo(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_SERVICIOS_EXTENSION.xlsx', 'SERV_EXT_POBL_GRUPO', 'ID_POBLACION_POR_GRUPO', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %%
def val_SERV_EXT_POBL_GRUPO_cantidad(sheet, col_name, fields_report):
  sheet_SERV_EXT_POBL_GRUPO_name = 'SERV_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_SERV_EXT_POBL_GRUPO_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
def SERVICIO_DE_EXTENSION_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'SERVICIOS DE EXTENSIÓN', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/SERVICIOS_DE_EXTENSIÓN_revisados/Revision_SERVICIO_EXTENSION_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'SERVICIOS_EXTENSION').to_excel(writer, 'SERVICIOS_EXTENSION', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_AREA_TRABAJO').to_excel(writer, 'SERV_EXT_AREA_TRABAJO', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_CICLO_VITAL').to_excel(writer, 'SERV_EXT_CICLO_VITAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_ENTIDAD_NACIONAL').to_excel(writer, 'SERV_EXT_ENTIDAD_NACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_FUENTE_NACIONAL').to_excel(writer, 'SERV_EXT_FUENTE_NACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_FUENTE_INTERNACIONAL').to_excel(writer, 'SERV_EXT_FUENTE_INTERNACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_OTRAS_ENTIDADES').to_excel(writer, 'SERV_EXT_OTRAS_ENTIDADES', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_POBL_CONDICION').to_excel(writer, 'SERV_EXT_POBL_CONDICION', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'SERV_EXT_POBL_GRUPO').to_excel(writer, 'SERV_EXT_POBL_GRUPO', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_SERVICIO_DE_EXTENSION(doc_name, general_path, year_open_period):
  fields_found_SERVICIO_EXTENSION = []     # to store the sheets and fields that were reviewed
  fields_not_found_SERVICIO_EXTENSION = []   # to store sheets and fields that were not found
  fields_report_SERVICIO_EXTENSION = {    # dictionary to store the findings of each field
      'SERVICIOS_EXTENSION' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'NOMBRE_SERVICIO':[],
          'DESCRIPCION_SERVICIO':[],
          'VALOR_SERVICIO':[],
          'ID_AREA_EXTENSION':[],
          'FECHA_INICIO':[],
          'FECHA_FINAL':[],
          'NOMBRE_CONTACTO':[],
          'APELLIDO_CONTACTO':[],
          'TELEFONO_CONTACTO':[],
          'EMAIL_CONTACTO':[],
          'TIENE_COSTO':[],
          'CRITERIO_ELEGIBILIDAD':[]
      },
      'SERV_EXT_AREA_TRABAJO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_AREA_TRABAJO':[]
      },
      'SERV_EXT_CICLO_VITAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_CICLO_VITAL':[]
      },
      'SERV_EXT_ENTIDAD_NACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_ENTIDAD_NACIONAL':[]
      },
      'SERV_EXT_FUENTE_NACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_FUENTE_NACIONAL':[],
          'VALOR_FINANCIACION':[]
      },
      'SERV_EXT_FUENTE_INTERNACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'NOMBRE_INSTITUCION':[],
          'ID_PAIS_FINANCIADOR':[],
          'ID_FUENTE_INTERNACIONAL':[],
          'VALOR_FINANCIACION':[]
      },
      'SERV_EXT_OTRAS_ENTIDADES' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'NOMBRE_ENTIDAD':[],
          'ID_PAIS_ENTIDAD':[],
          'ID_SECTOR_ENTIDAD':[]
      },
      'SERV_EXT_POBL_CONDICION' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_POBLACION_POR_CONDICION':[],
          'CANTIDAD':[]
      },
      'SERV_EXT_POBL_GRUPO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_POBLACION_POR_GRUPO':[],
          'CANTIDAD':[]
      }
  }

  # sheet validation < SERVICIOS_EXTENSION >
  try:    # try to search, open and validate the sheet 'SERVICIOS_EXTENSION'

    servicios_extension_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERVICIOS_EXTENSION')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERVICIOS_EXTENSION')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_ano(servicios_extension_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_semestre(servicios_extension_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_codigo_unidad_organizacional(servicios_extension_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_codigo_servicio(servicios_extension_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('NOMBRE_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_nombre_servicio(servicios_extension_sheet, 'NOMBRE_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('DESCRIPCION_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_descripcion_servicio(servicios_extension_sheet, 'DESCRIPCION_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('VALOR_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_valor_servicio(servicios_extension_sheet, 'VALOR_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_AREA_EXTENSION', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_id_area_extension(servicios_extension_sheet, 'ID_AREA_EXTENSION', fields_report_SERVICIO_EXTENSION))
    validate_column('FECHA_INICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_fecha_inicio(servicios_extension_sheet, 'FECHA_INICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('FECHA_FINAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_fecha_final(servicios_extension_sheet, 'FECHA_FINAL', fields_report_SERVICIO_EXTENSION))
    validate_column('NOMBRE_CONTACTO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_nombre_contacto(servicios_extension_sheet, 'NOMBRE_CONTACTO', fields_report_SERVICIO_EXTENSION))
    validate_column('APELLIDO_CONTACTO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_apellido_contacto(servicios_extension_sheet, 'APELLIDO_CONTACTO', fields_report_SERVICIO_EXTENSION))
    validate_column('TELEFONO_CONTACTO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_telefono_contacto(servicios_extension_sheet, 'TELEFONO_CONTACTO', fields_report_SERVICIO_EXTENSION))
    validate_column('EMAIL_CONTACTO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_email_contacto(servicios_extension_sheet, 'EMAIL_CONTACTO', fields_report_SERVICIO_EXTENSION))
    validate_column('TIENE_COSTO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_tiene_costo(servicios_extension_sheet, 'TIENE_COSTO', fields_report_SERVICIO_EXTENSION))
    validate_column('CRITERIO_ELEGIBILIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERVICIOS_EXTENSION_criterio_elegibilidad(servicios_extension_sheet, 'CRITERIO_ELEGIBILIDAD', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERVICIOS_EXTENSION')     # sheet < CURSO > not found

  # sheet validation < SERV_EXT_AREA_TRABAJO >
  try:    # try to search, open and validate the sheet 'SERV_EXT_AREA_TRABAJO'

    serv_ext_area_trabajo_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_AREA_TRABAJO')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_AREA_TRABAJO')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_AREA_TRABAJO_ano(serv_ext_area_trabajo_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_AREA_TRABAJO_semestre(serv_ext_area_trabajo_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_AREA_TRABAJO_codigo_unidad_organizacional(serv_ext_area_trabajo_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_AREA_TRABAJO_codigo_servicio(serv_ext_area_trabajo_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_AREA_TRABAJO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_AREA_TRABAJO_id_area_trabajo(serv_ext_area_trabajo_sheet, 'ID_AREA_TRABAJO', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_AREA_TRABAJO')     # sheet < SERV_EXT_AREA_TRABAJO > not found

  # sheet validation < SERV_EXT_CICLO_VITAL >
  try:    # try to search, open and validate the sheet 'SERV_EXT_CICLO_VITAL'

    serv_ext_ciclo_vital_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_CICLO_VITAL')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_CICLO_VITAL')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_CICLO_VITAL_ano(serv_ext_ciclo_vital_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_CICLO_VITAL_semestre(serv_ext_ciclo_vital_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_CICLO_VITAL_codigo_unidad_organizacional(serv_ext_ciclo_vital_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_CICLO_VITAL_codigo_servicio(serv_ext_ciclo_vital_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_CICLO_VITAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_CICLO_VITAL_id_ciclo_vital(serv_ext_ciclo_vital_sheet, 'ID_CICLO_VITAL', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_CICLO_VITAL')     # sheet < SERV_EXT_CICLO_VITAL > not found

  # sheet validation < SERV_EXT_ENTIDAD_NACIONAL >
  try:    # try to search, open and validate the sheet 'SERV_EXT_ENTIDAD_NACIONAL'

    serv_ext_entidad_nacional_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_ENTIDAD_NACIONAL')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_ENTIDAD_NACIONAL')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_ENTIDAD_NACIONAL_ano(serv_ext_entidad_nacional_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_ENTIDAD_NACIONAL_semestre(serv_ext_entidad_nacional_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_ENTIDAD_NACIONAL_codigo_unidad_organizacional(serv_ext_entidad_nacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_ENTIDAD_NACIONAL_codigo_servicio(serv_ext_entidad_nacional_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_ENTIDAD_NACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_ENTIDAD_NACIONAL_id_entidad_nacional(serv_ext_entidad_nacional_sheet, 'ID_ENTIDAD_NACIONAL', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_ENTIDAD_NACIONAL')     # sheet < SERV_EXT_ENTIDAD_NACIONAL > not found

  # sheet validation < SERV_EXT_FUENTE_NACIONAL >
  try:    # try to search, open and validate the sheet 'SERV_EXT_FUENTE_NACIONAL'

    serv_ext_fuente_nacional_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_FUENTE_NACIONAL')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_FUENTE_NACIONAL')    # # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_ano(serv_ext_fuente_nacional_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_semestre(serv_ext_fuente_nacional_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_codigo_unidad_organizacional(serv_ext_fuente_nacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_codigo_servicio(serv_ext_fuente_nacional_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_FUENTE_NACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_id_fuente_nacional(serv_ext_fuente_nacional_sheet, 'ID_FUENTE_NACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('VALOR_FINANCIACION', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_NACIONAL_valor_financiacion(serv_ext_fuente_nacional_sheet, 'VALOR_FINANCIACION', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_FUENTE_NACIONAL')     # sheet < SERV_EXT_FUENTE_NACIONAL > not found

  # sheet validation < SERV_EXT_FUENTE_INTERNACIONAL >
  try:    # try to search, open and validate the sheet 'SERV_EXT_FUENTE_INTERNACIONAL'

    serv_ext_fuente_internacional_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_FUENTE_INTERNACIONAL')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_FUENTE_INTERNACIONAL')    # # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_ano(serv_ext_fuente_internacional_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_semestre(serv_ext_fuente_internacional_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_codigo_unidad_organizacional(serv_ext_fuente_internacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_codigo_servicio(serv_ext_fuente_internacional_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('NOMBRE_INSTITUCION', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_nombre_institucion(serv_ext_fuente_internacional_sheet, 'NOMBRE_INSTITUCION', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_PAIS_FINANCIADOR', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_id_pais_financiador(serv_ext_fuente_internacional_sheet, 'ID_PAIS_FINANCIADOR', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_FUENTE_INTERNACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_id_fuente_internacional(serv_ext_fuente_internacional_sheet, 'ID_FUENTE_INTERNACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('VALOR_FINANCIACION', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_FUENTE_INTERNACIONAL_valor_financiacion(serv_ext_fuente_internacional_sheet, 'VALOR_FINANCIACION', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_FUENTE_INTERNACIONAL')     # sheet < SERV_EXT_FUENTE_INTERNACIONAL > not found

  # sheet validation < SERV_EXT_OTRAS_ENTIDADES >
  try:    # try to search, open and validate the sheet 'SERV_EXT_OTRAS_ENTIDADES'

    serv_ext_otras_entidades_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_OTRAS_ENTIDADES')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_OTRAS_ENTIDADES')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_ano(serv_ext_otras_entidades_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_semestre(serv_ext_otras_entidades_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_codigo_unidad_organizacional(serv_ext_otras_entidades_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_codigo_servicio(serv_ext_otras_entidades_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('NOMBRE_ENTIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_nombre_entidad(serv_ext_otras_entidades_sheet, 'NOMBRE_ENTIDAD', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_PAIS_ENTIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_id_pais_entidad(serv_ext_otras_entidades_sheet, 'ID_PAIS_ENTIDAD', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_SECTOR_ENTIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_OTRAS_ENTIDADES_id_sector_entidad(serv_ext_otras_entidades_sheet, 'ID_SECTOR_ENTIDAD', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_OTRAS_ENTIDADES')     # sheet < SERV_EXT_OTRAS_ENTIDADES > not found

  # sheet validation < SERV_EXT_POBL_CONDICION >
  try:    # try to search, open and validate the sheet 'SERV_EXT_POBL_CONDICION'

    serv_ext_pobl_condicion_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_POBL_CONDICION')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_POBL_CONDICION')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_ano(serv_ext_pobl_condicion_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_semestre(serv_ext_pobl_condicion_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_codigo_unidad_organizacional(serv_ext_pobl_condicion_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_codigo_servicio(serv_ext_pobl_condicion_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_POBLACION_POR_CONDICION', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_id_poblacion_por_condicion(serv_ext_pobl_condicion_sheet, 'ID_POBLACION_POR_CONDICION', fields_report_SERVICIO_EXTENSION))
    validate_column('CANTIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_CONDICION_cantidad(serv_ext_pobl_condicion_sheet, 'CANTIDAD', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_POBL_CONDICION')     # sheet < SERV_EXT_POBL_CONDICION > not found

  # sheet validation < SERV_EXT_POBL_GRUPO >
  try:    # try to search, open and validate the sheet 'SERV_EXT_POBL_GRUPO'

    serv_ext_pobl_grupo_sheet = pd.read_excel(general_path + '11.6. SERVICIOS DE EXTENSIÓN/' + doc_name, sheet_name='SERV_EXT_POBL_GRUPO')     # open excel
    fields_found_SERVICIO_EXTENSION.append('SERV_EXT_POBL_GRUPO')    # if found, stored

    validate_column('AÑO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_ano(serv_ext_pobl_grupo_sheet, 'AÑO', fields_report_SERVICIO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_semestre(serv_ext_pobl_grupo_sheet, 'SEMESTRE', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_codigo_unidad_organizacional(serv_ext_pobl_grupo_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_SERVICIO_EXTENSION))
    validate_column('CODIGO_SERVICIO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_codigo_servicio(serv_ext_pobl_grupo_sheet, 'CODIGO_SERVICIO', fields_report_SERVICIO_EXTENSION))
    validate_column('ID_POBLACION_POR_GRUPO', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_id_poblacion_por_grupo(serv_ext_pobl_grupo_sheet, 'ID_POBLACION_POR_GRUPO', fields_report_SERVICIO_EXTENSION))
    validate_column('CANTIDAD', fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION,
                    val_SERV_EXT_POBL_GRUPO_cantidad(serv_ext_pobl_grupo_sheet, 'CANTIDAD', fields_report_SERVICIO_EXTENSION))

  except ValueError:
    fields_not_found_SERVICIO_EXTENSION.append('SERV_EXT_POBL_GRUPO')     # sheet < SERV_EXT_POBL_GRUPO > not found

  SERVICIO_DE_EXTENSION_report(doc_name, general_path, fields_found_SERVICIO_EXTENSION, fields_not_found_SERVICIO_EXTENSION, fields_report_SERVICIO_EXTENSION)

# %% [markdown]
# >> ### loop through all the files in the folder '11.6 SERVICIOS DE EXTENSIÓN'

# %%
def running_11_6_SERVICIOS_DE_EXTENSION(general_path, year_open_period):
  servicio_extension_path = Path(general_path + '11.6. SERVICIOS DE EXTENSIÓN/')
  for entry in servicio_extension_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_SERVICIO_DE_EXTENSION(doc_name, general_path, year_open_period)    # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# > # 11.7. **Proyecto de extensión**

# %% [markdown]
# >> ### validation functions of each column of the sheets:

# %% [markdown]
# #### 'PROYECTOS_EXTENSION'

# %%
def val_PROYECTOS_EXTENSION_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_semestre(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROYECTOS_EXTENSION', 'SEMESTRE', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_nombre_proyecto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 400, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_descripcion_proyecto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 250, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    # Este campo no requiere una validación específica

# %%
def val_PROYECTOS_EXTENSION_valor_proyecto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_id_area_extension(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROYECTOS_EXTENSION', 'ID_AREA_EXTENSION', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_fecha_inicio(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < date >
    validate_type(cell, index_cell, 'date', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    validate_date_80_years_before(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_fecha_final(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < date >
    validate_type(cell, index_cell, 'date', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    # Este campo no requiere una longitud específica

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_final_date_older_initial_date(cell, index_cell, sheet, 'FECHA_INICIO', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_nombre_contacto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_apellido_contacto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_telefono_contacto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    validate_phone(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %%
def val_PROYECTOS_EXTENSION_email_contacto(sheet, col_name, fields_report):
  sheet_PROYECTOS_EXTENSION_name = 'PROYECTOS_EXTENSION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 50, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)
    val_email(cell, index_cell, fields_report, sheet_PROYECTOS_EXTENSION_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_AREA_TRABAJO'

# %%
def val_PROY_EXT_AREA_TRABAJO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_AREA_TRABAJO_name = 'PROY_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_PROY_EXT_AREA_TRABAJO_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_AREA_TRABAJO_name = 'PROY_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_AREA_TRABAJO', 'SEMESTRE', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_PROY_EXT_AREA_TRABAJO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_AREA_TRABAJO_name = 'PROY_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_PROY_EXT_AREA_TRABAJO_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_AREA_TRABAJO_name = 'PROY_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

# %%
def val_PROY_EXT_AREA_TRABAJO_id_area_trabajo(sheet, col_name, fields_report):
  sheet_PROY_EXT_AREA_TRABAJO_name = 'PROY_EXT_AREA_TRABAJO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_AREA_TRABAJO', 'ID_AREA_TRABAJO', fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_AREA_TRABAJO_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_CICLO_VITAL'

# %%
def val_PROY_EXT_CICLO_VITAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_CICLO_VITAL_name = 'PROY_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

# %%
def val_PROY_EXT_CICLO_VITAL_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_CICLO_VITAL_name = 'PROY_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_CICLO_VITAL', 'SEMESTRE', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

# %%
def val_PROY_EXT_CICLO_VITAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_CICLO_VITAL_name = 'PROY_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

# %%
def val_PROY_EXT_CICLO_VITAL_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_CICLO_VITAL_name = 'PROY_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

# %%
def val_PROY_EXT_CICLO_VITAL_id_ciclo_vital(sheet, col_name, fields_report):
  sheet_PROY_EXT_CICLO_VITAL_name = 'PROY_EXT_CICLO_VITAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_CICLO_VITAL', 'ID_CICLO_VITAL', fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_CICLO_VITAL_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_ENTIDAD_NACIONAL'

# %%
def val_PROY_EXT_ENTIDAD_NACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_ENTIDAD_NACIONAL_name = 'PROY_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_ENTIDAD_NACIONAL_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_ENTIDAD_NACIONAL_name = 'PROY_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_ENTIDAD_NACIONAL', 'SEMESTRE', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_ENTIDAD_NACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_ENTIDAD_NACIONAL_name = 'PROY_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_ENTIDAD_NACIONAL_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_ENTIDAD_NACIONAL_name = 'PROY_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_ENTIDAD_NACIONAL_id_entidad_nacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_ENTIDAD_NACIONAL_name = 'PROY_EXT_ENTIDAD_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_ENTIDAD_NACIONAL', 'ID_ENTIDAD_NACIONAL', fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_ENTIDAD_NACIONAL_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_FUENTE_NACIONAL'

# %%
def val_PROY_EXT_FUENTE_NACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_NACIONAL_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_FUENTE_NACIONAL', 'SEMESTRE', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_NACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_NACIONAL_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_NACIONAL_id_fuente_nacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_FUENTE_NACIONAL', 'ID_FUENTE_NACIONAL', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_NACIONAL_valor_financiacion(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_NACIONAL_name = 'PROY_EXT_FUENTE_NACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_NACIONAL_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_FUENTE_INTERNACIONAL'

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_FUENTE_INTERNACIONAL', 'SEMESTRE', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_nombre_institucion(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_id_pais_financiador(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_FUENTE_INTERNACIONAL', 'ID_PAIS_FINANCIADOR', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_not_Colombia(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_id_fuente_internacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_FUENTE_INTERNACIONAL', 'ID_FUENTE_INTERNACIONAL', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %%
def val_PROY_EXT_FUENTE_INTERNACIONAL_valor_financiacion(sheet, col_name, fields_report):
  sheet_PROY_EXT_FUENTE_INTERNACIONAL_name = 'PROY_EXT_FUENTE_INTERNACIONAL'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROY_EXT_FUENTE_INTERNACIONAL_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_OTRAS_ENTIDADES'

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_OTRAS_ENTIDADES', 'SEMESTRE', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_codigo_proyeto(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_nombre_entidad(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 200, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_id_pais_entidad(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 3, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_OTRAS_ENTIDADES', 'ID_PAIS_ENTIDAD', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %%
def val_PROY_EXT_OTRAS_ENTIDADES_id_sector_entidad(sheet, col_name, fields_report):
  sheet_PROY_EXT_OTRAS_ENTIDADES_name = 'PROY_EXT_OTRAS_ENTIDADES'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_OTRAS_ENTIDADES', 'ID_SECTOR_ENTIDAD', fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_OTRAS_ENTIDADES_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_POBL_CONDICION'

# %%
def val_PROY_EXT_POBL_CONDICION_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %%
def val_PROY_EXT_POBL_CONDICION_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_POBL_CONDICION', 'SEMESTRE', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %%
def val_PROY_EXT_POBL_CONDICION_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %%
def val_PROY_EXT_POBL_CONDICION_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %%
def val_PROY_EXT_POBL_CONDICION_id_poblacion_por_condicion(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_POBL_CONDICION', 'ID_POBLACION_POR_CONDICION', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %%
def val_PROY_EXT_POBL_CONDICION_cantidad(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_CONDICION_name = 'PROY_EXT_POBL_CONDICION'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_CONDICION_name, col_name)

# %% [markdown]
# #### 'PROY_EXT_POBL_GRUPO'

# %%
def val_PROY_EXT_POBL_GRUPO_ano(sheet, col_name, fields_report, year_open_period):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 4, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    validate_year_open_period(cell, index_cell, year_open_period,fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %%
def val_PROY_EXT_POBL_GRUPO_semestre(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 1, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_POBL_GRUPO', 'SEMESTRE', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %%
def val_PROY_EXT_POBL_GRUPO_codigo_unidad_organizacional(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 30, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %%
def val_PROY_EXT_POBL_GRUPO_codigo_proyecto(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < alfanumerico >
    validate_type(cell, index_cell, 'alphanumeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Validación de la longitud del dato
    validate_lenght(cell, index_cell, 15, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %%
def val_PROY_EXT_POBL_GRUPO_id_poblacion_por_grupo(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 2, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    validate_values(cell, index_cell, 'valid_values_PROYECTO_DE_EXTENSIÓN.xlsx', 'PROY_EXT_POBL_GRUPO', 'ID_POBLACION_POR_GRUPO', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %%
def val_PROY_EXT_POBL_GRUPO_cantidad(sheet, col_name, fields_report):
  sheet_PROY_EXT_POBL_GRUPO_name = 'PROY_EXT_POBL_GRUPO'
  index_cell = 1
  for cell in sheet[col_name]:
    index_cell += 1

    # Validación de tipo de dato < numerico >
    validate_type(cell, index_cell, 'numeric', fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

    try:
      cell = int(cell)
      # Validación de la longitud del dato
      validate_lenght(cell, index_cell, 10, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    except:
      pass

    # Validación de valores validos
    # Este campo no requiere valores específicos

    # Otras validaciones
    validate_required(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)
    validate_negative(cell, index_cell, fields_report, sheet_PROY_EXT_POBL_GRUPO_name, col_name)

# %% [markdown]
# >> ### generates the excel with the results of the review, that is, with all the validations, which are the cells that do not comply and why they do not comply

# %%
def PROYECTO_EXTENSION_report(doc_name, general_path, fields_found, fields_not_found, fields_report):
  ''' Generates the excel document of the validations results '''
  date = str(datetime.datetime.now(zoneinfo.ZoneInfo("America/Bogota")))    # Generate the actual time

  general_report = report_general_funct(date, doc_name, 'PROYECTO DE EXTENSIÓN', fields_found, fields_not_found)
  writer = pd.ExcelWriter(general_path + 'REVISIONES/PROYECTO_DE_EXTENSION_revisados/Revision_PROYECTO_EXTENSION_' + date + '.xlsx') # dataframe to excel
  general_report.to_excel(writer, 'Reporte general', index = False)
  sheet_df_generate(fields_report, 'PROYECTOS_EXTENSION').to_excel(writer, 'PROYECTOS_EXTENSION', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_AREA_TRABAJO').to_excel(writer, 'PROY_EXT_AREA_TRABAJO', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_CICLO_VITAL').to_excel(writer, 'PROY_EXT_CICLO_VITAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_ENTIDAD_NACIONAL').to_excel(writer, 'PROY_EXT_ENTIDAD_NACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_FUENTE_NACIONAL').to_excel(writer, 'PROY_EXT_FUENTE_NACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_FUENTE_INTERNACIONAL').to_excel(writer, 'PROY_EXT_FUENTE_INTERNACIONAL', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_OTRAS_ENTIDADES').to_excel(writer, 'PROY_EXT_OTRAS_ENTIDADES', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_POBL_CONDICION').to_excel(writer, 'PROY_EXT_POBL_CONDICION', index = False )    # add other sheet for the specific data
  sheet_df_generate(fields_report, 'PROY_EXT_POBL_GRUPO').to_excel(writer, 'PROY_EXT_POBL_GRUPO', index = False )    # add other sheet for the specific data

  writer.save()

# %% [markdown]
# >> ### validation function of each file

# %%
def validate_PROYECTO_DE_EXTENSION(doc_name, general_path, year_open_period):
  fields_found_PROYECTO_EXTENSION = []     # to store the sheets and fields that were reviewed
  fields_not_found_PROYECTO_EXTENSION = []   # to store sheets and fields that were not found
  fields_report_PROYECTO_EXTENSION = {    # dictionary to store the findings of each field
      'PROYECTOS_EXTENSION' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'NOMBRE_PROYECTO':[],
          'DESCRIPCION_PROYECTO':[],
          'VALOR_PROYECTO':[],
          'ID_AREA_EXTENSION':[],
          'FECHA_INICIO':[],
          'FECHA_FINAL':[],
          'NOMBRE_CONTACTO':[],
          'APELLIDO_CONTACTO':[],
          'TELEFONO_CONTACTO':[],
          'EMAIL_CONTACTO':[]
      },
      'PROY_EXT_AREA_TRABAJO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'ID_AREA_TRABAJO':[]
      },
      'PROY_EXT_CICLO_VITAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'ID_CICLO_VITAL':[]
      },
      'PROY_EXT_ENTIDAD_NACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'ID_ENTIDAD_NACIONAL':[]
      },
      'PROY_EXT_FUENTE_NACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'ID_FUENTE_NACIONAL':[],
          'VALOR_FINANCIACION':[]
      },
      'PROY_EXT_FUENTE_INTERNACIONAL' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'NOMBRE_INSTITUCION':[],
          'ID_PAIS_FINANCIADOR':[],
          'ID_FUENTE_INTERNACIONAL':[],
          'VALOR_FINANCIACION':[]
      },
      'PROY_EXT_OTRAS_ENTIDADES' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'NOMBRE_ENTIDAD':[],
          'ID_PAIS_ENTIDAD':[],
          'ID_SECTOR_ENTIDAD':[]
      },
      'PROY_EXT_POBL_CONDICION' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_SERVICIO':[],
          'ID_POBLACION_POR_CONDICION':[],
          'CANTIDAD':[]
      },
      'PROY_EXT_POBL_GRUPO' : {
          'AÑO':[],
          'SEMESTRE':[],
          'CODIGO_UNIDAD_ORGANIZACIONAL':[],
          'CODIGO_PROYECTO':[],
          'ID_POBLACION_POR_GRUPO':[],
          'CANTIDAD':[]
      }
  }

  # sheet validation < PROYECTOS_EXTENSION >
  try:    # try to search, open and validate the sheet 'PROYECTOS_EXTENSION'

    proyecto_extension_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROYECTOS_EXTENSION')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROYECTOS_EXTENSION')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_ano(proyecto_extension_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_semestre(proyecto_extension_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_codigo_unidad_organizacional(proyecto_extension_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_codigo_proyecto(proyecto_extension_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('NOMBRE_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_nombre_proyecto(proyecto_extension_sheet, 'NOMBRE_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('DESCRIPCION_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_descripcion_proyecto(proyecto_extension_sheet, 'DESCRIPCION_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('VALOR_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_valor_proyecto(proyecto_extension_sheet, 'VALOR_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_AREA_EXTENSION', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_id_area_extension(proyecto_extension_sheet, 'ID_AREA_EXTENSION', fields_report_PROYECTO_EXTENSION))
    validate_column('FECHA_INICIO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_fecha_inicio(proyecto_extension_sheet, 'FECHA_INICIO', fields_report_PROYECTO_EXTENSION))
    validate_column('FECHA_FINAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_fecha_final(proyecto_extension_sheet, 'FECHA_FINAL', fields_report_PROYECTO_EXTENSION))
    validate_column('NOMBRE_CONTACTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_nombre_contacto(proyecto_extension_sheet, 'NOMBRE_CONTACTO', fields_report_PROYECTO_EXTENSION))
    validate_column('APELLIDO_CONTACTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_apellido_contacto(proyecto_extension_sheet, 'APELLIDO_CONTACTO', fields_report_PROYECTO_EXTENSION))
    validate_column('TELEFONO_CONTACTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_telefono_contacto(proyecto_extension_sheet, 'TELEFONO_CONTACTO', fields_report_PROYECTO_EXTENSION))
    validate_column('EMAIL_CONTACTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROYECTOS_EXTENSION_email_contacto(proyecto_extension_sheet, 'EMAIL_CONTACTO', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROYECTOS_EXTENSION')     # sheet < PROYECTOS_EXTENSION > not found

  # sheet validation < PROY_EXT_AREA_TRABAJO >
  try:    # try to search, open and validate the sheet 'PROY_EXT_AREA_TRABAJO'

    proy_ext_area_trabajo_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_AREA_TRABAJO')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_AREA_TRABAJO')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_AREA_TRABAJO_ano(proy_ext_area_trabajo_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_AREA_TRABAJO_semestre(proy_ext_area_trabajo_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_AREA_TRABAJO_codigo_unidad_organizacional(proy_ext_area_trabajo_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_AREA_TRABAJO_codigo_proyecto(proy_ext_area_trabajo_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_AREA_TRABAJO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_AREA_TRABAJO_id_area_trabajo(proy_ext_area_trabajo_sheet, 'ID_AREA_TRABAJO', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_AREA_TRABAJO')     # sheet < PROY_EXT_AREA_TRABAJO > not found

  # sheet validation < PROY_EXT_CICLO_VITAL >
  try:    # try to search, open and validate the sheet 'PROY_EXT_CICLO_VITAL'

    proy_ext_ciclo_vital_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_CICLO_VITAL')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_CICLO_VITAL')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_CICLO_VITAL_ano(proy_ext_ciclo_vital_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_CICLO_VITAL_semestre(proy_ext_ciclo_vital_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_CICLO_VITAL_codigo_unidad_organizacional(proy_ext_ciclo_vital_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_CICLO_VITAL_codigo_proyecto(proy_ext_ciclo_vital_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_CICLO_VITAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_CICLO_VITAL_id_ciclo_vital(proy_ext_ciclo_vital_sheet, 'ID_CICLO_VITAL', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_CICLO_VITAL')     # sheet < PROY_EXT_CICLO_VITAL > not found

  # sheet validation < PROY_EXT_ENTIDAD_NACIONAL >
  try:    # try to search, open and validate the sheet 'PROY_EXT_ENTIDAD_NACIONAL'

    proy_ext_entidad_nacional_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_ENTIDAD_NACIONAL')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_ENTIDAD_NACIONAL')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_ENTIDAD_NACIONAL_ano(proy_ext_entidad_nacional_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_ENTIDAD_NACIONAL_semestre(proy_ext_entidad_nacional_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_ENTIDAD_NACIONAL_codigo_unidad_organizacional(proy_ext_entidad_nacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_ENTIDAD_NACIONAL_codigo_proyecto(proy_ext_entidad_nacional_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_ENTIDAD_NACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_ENTIDAD_NACIONAL_id_entidad_nacional(proy_ext_entidad_nacional_sheet, 'ID_ENTIDAD_NACIONAL', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_ENTIDAD_NACIONAL')     # sheet < PROY_EXT_ENTIDAD_NACIONAL > not found

  # sheet validation < PROY_EXT_FUENTE_NACIONAL >
  try:    # try to search, open and validate the sheet 'PROY_EXT_FUENTE_NACIONAL'

    proy_ext_fuente_nacional_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_FUENTE_NACIONAL')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_FUENTE_NACIONAL')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_ano(proy_ext_fuente_nacional_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_semestre(proy_ext_fuente_nacional_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_codigo_unidad_organizacional(proy_ext_fuente_nacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_codigo_proyecto(proy_ext_fuente_nacional_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_FUENTE_NACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_id_fuente_nacional(proy_ext_fuente_nacional_sheet, 'ID_FUENTE_NACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('VALOR_FINANCIACION', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_NACIONAL_valor_financiacion(proy_ext_fuente_nacional_sheet, 'VALOR_FINANCIACION', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_FUENTE_NACIONAL')     # sheet < PROY_EXT_FUENTE_NACIONAL > not found

  # sheet validation < PROY_EXT_FUENTE_INTERNACIONAL >
  try:    # try to search, open and validate the sheet 'PROY_EXT_FUENTE_INTERNACIONAL'

    proy_ext_fuente_internacional_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_FUENTE_INTERNACIONAL')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_FUENTE_INTERNACIONAL')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_ano(proy_ext_fuente_internacional_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_semestre(proy_ext_fuente_internacional_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_codigo_unidad_organizacional(proy_ext_fuente_internacional_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_codigo_proyecto(proy_ext_fuente_internacional_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('NOMBRE_INSTITUCION', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_nombre_institucion(proy_ext_fuente_internacional_sheet, 'NOMBRE_INSTITUCION', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_PAIS_FINANCIADOR', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_id_fuente_internacional(proy_ext_fuente_internacional_sheet, 'ID_PAIS_FINANCIADOR', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_FUENTE_INTERNACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_id_fuente_internacional(proy_ext_fuente_internacional_sheet, 'ID_FUENTE_INTERNACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('VALOR_FINANCIACION', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_FUENTE_INTERNACIONAL_valor_financiacion(proy_ext_fuente_internacional_sheet, 'VALOR_FINANCIACION', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_FUENTE_INTERNACIONAL')     # sheet < PROY_EXT_FUENTE_INTERNACIONAL > not found

  # sheet validation < PROY_EXT_OTRAS_ENTIDADES >
  try:    # try to search, open and validate the sheet 'PROY_EXT_OTRAS_ENTIDADES'

    proy_ext_otras_entidades_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_OTRAS_ENTIDADES')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_OTRAS_ENTIDADES')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_ano(proy_ext_otras_entidades_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_semestre(proy_ext_otras_entidades_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_codigo_unidad_organizacional(proy_ext_otras_entidades_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_codigo_proyeto(proy_ext_otras_entidades_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('NOMBRE_ENTIDAD', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_nombre_entidad(proy_ext_otras_entidades_sheet, 'NOMBRE_ENTIDAD', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_PAIS_ENTIDAD', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_id_pais_entidad(proy_ext_otras_entidades_sheet, 'ID_PAIS_ENTIDAD', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_SECTOR_ENTIDAD', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_OTRAS_ENTIDADES_id_sector_entidad(proy_ext_otras_entidades_sheet, 'ID_SECTOR_ENTIDAD', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_OTRAS_ENTIDADES')     # sheet < PROY_EXT_OTRAS_ENTIDADES > not found

  # sheet validation < PROY_EXT_POBL_CONDICION >
  try:    # try to search, open and validate the sheet 'PROY_EXT_POBL_CONDICION'

    proy_ext_pobl_condicion_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_POBL_CONDICION')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_POBL_CONDICION')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_ano(proy_ext_pobl_condicion_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_semestre(proy_ext_pobl_condicion_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_codigo_unidad_organizacional(proy_ext_pobl_condicion_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_codigo_proyecto(proy_ext_pobl_condicion_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_POBLACION_POR_CONDICION', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_id_poblacion_por_condicion(proy_ext_pobl_condicion_sheet, 'ID_POBLACION_POR_CONDICION', fields_report_PROYECTO_EXTENSION))
    validate_column('CANTIDAD', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_CONDICION_cantidad(proy_ext_pobl_condicion_sheet, 'CANTIDAD', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_POBL_CONDICION')     # sheet < PROY_EXT_POBL_CONDICION > not found

  # sheet validation < PROY_EXT_POBL_GRUPO >
  try:    # try to search, open and validate the sheet 'PROY_EXT_POBL_GRUPO'

    proy_ext_pobl_grupo_sheet = pd.read_excel(general_path + '11.7. PROYECTO DE EXTENSIÓN/' + doc_name, sheet_name='PROY_EXT_POBL_GRUPO')     # open excel
    fields_found_PROYECTO_EXTENSION.append('PROY_EXT_POBL_GRUPO')    # if found, stored

    validate_column('AÑO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_ano(proy_ext_pobl_grupo_sheet, 'AÑO', fields_report_PROYECTO_EXTENSION, year_open_period))
    validate_column('SEMESTRE', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_semestre(proy_ext_pobl_grupo_sheet, 'SEMESTRE', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_UNIDAD_ORGANIZACIONAL', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_codigo_unidad_organizacional(proy_ext_pobl_grupo_sheet, 'CODIGO_UNIDAD_ORGANIZACIONAL', fields_report_PROYECTO_EXTENSION))
    validate_column('CODIGO_PROYECTO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_codigo_proyecto(proy_ext_pobl_grupo_sheet, 'CODIGO_PROYECTO', fields_report_PROYECTO_EXTENSION))
    validate_column('ID_POBLACION_POR_GRUPO', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_id_poblacion_por_grupo(proy_ext_pobl_grupo_sheet, 'ID_POBLACION_POR_GRUPO', fields_report_PROYECTO_EXTENSION))
    validate_column('CANTIDAD', fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION,
                    val_PROY_EXT_POBL_GRUPO_cantidad(proy_ext_pobl_grupo_sheet, 'CANTIDAD', fields_report_PROYECTO_EXTENSION))

  except ValueError:
    fields_not_found_PROYECTO_EXTENSION.append('PROY_EXT_POBL_GRUPO')     # sheet < PROY_EXT_POBL_GRUPO > not found


  PROYECTO_EXTENSION_report(doc_name, general_path, fields_found_PROYECTO_EXTENSION, fields_not_found_PROYECTO_EXTENSION, fields_report_PROYECTO_EXTENSION)

# %% [markdown]
# >> ### loop through all the files in the folder '11.7 PROYECTOS DE EXTENSIÓN'

# %%
def running_11_7_PROYECTO_DE_EXTENSION(general_path, year_open_period):
  proyecto_extension_path = Path(general_path + '11.7. PROYECTO DE EXTENSIÓN/')
  for entry in proyecto_extension_path.iterdir():   # here is where are stored the names of files, so it's iterates
    try:
      doc_name = entry.name    # here is the name of each file
      validate_PROYECTO_DE_EXTENSION(doc_name, general_path, year_open_period)    # here is where each file is validated
    except:
      print('----->  Ha habido un error validando este archivo: ' + doc_name)

# %% [markdown]
# # NOTAS
#
# *   Cuando el tipo de dato es númerico, al hacer la validación de la longitud, toma en cuenta los decimales, por ende se debe pasar primero a tipo entero para que la longitud sea la correct ay no tome en cuenta el punto y el cero. Así: 1.0, la logitud es 1, pero con la función de validación la longitud sería 3, es por eso que se debe pasar a entero.
# *   Cuando toda la hoja de excel está vacía el tamaño del dataframe es 0, entonces reconoce los nombres de las columnas, pero no es capaz de informar que los datos están vacíos y son requeridos

# %% [markdown]
# #Referencies
#
# https://decodigo.com/python-crear-un-archivo-de-excel-con-pandas
#
# https://www.codigopiton.com/como-obtener-la-hora-actual-en-python/#4-obtener-fecha-y-hora-actuales-por-timezone-
