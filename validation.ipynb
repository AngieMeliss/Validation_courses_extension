# %% [markdown]
# # Validación de plantillas de extensión:
# Ministerio de Educación HECAA V4.9
#
# ---

# %% [markdown]
# > # **Importando librerias**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import pathlib
from pathlib import Path
# !pip install email-validator
from email_validator import validate_email, EmailNotValidError
import itertools
import datetime
import zoneinfo
import pandas as pd
import numpy as np
from numpy import empty

# %% [markdown]
# > # **Ejecutar el código**

# %%
# %run '/content/gdrive/MyDrive/Validaciones_MEN_11_EXTENSIÓN/validaciones_por_plantilla.ipynb'

year_open_period = 2022
general_path = '/content/gdrive/MyDrive/Validaciones_MEN_11_EXTENSIÓN/'

start_up_all_functions(general_path, year_open_period)
